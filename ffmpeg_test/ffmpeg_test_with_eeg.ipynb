# %%
# Write down all paths.


PATH1 = r"C:\Users\enesy\Videos\xd\1.mp4"
PATH2 = r"C:\Users\enesy\Videos\xd\2.MOV"
PATH3 = r"C:\Users\enesy\Videos\xd\3.mp4"
PATH4 = r"C:\Users\enesy\Videos\xd\4.MP4"
EEG1 = r"C:\Users\enesy\Videos\xd\EEG_recording_2024-11-16-09.47.06.csv"

all_paths = [PATH1, PATH2, PATH3, PATH4]

# %%
# We need to know the durations of videos
# We will update these as we go.

from moviepy import VideoFileClip
import numpy as np

durations = [VideoFileClip(path).duration for path in all_paths]
longest_video_index = np.argmax(durations)
longest_video_path = all_paths[longest_video_index]
# Out:
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'avc1', 'minor_version': '0', 'compatible_brands': 'avc1isom', 'creation_time': '2024-11-16T09:45:49.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1920, 1080], 'bitrate': 23988, 'fps': 25.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'rotate': 180.0, 'creation_time': '2024-11-16T09:45:49.000000Z', 'handler_name': 'Ambarella AVC', 'encoder': 'Ambarella AVC encoder', 'Side data': '', 'displaymatrix': 'rotation of -180.00 degrees'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': 'eng', 'default': True, 'fps': 48000, 'bitrate': 192, 'metadata': {'rotate': '180', 'creation_time': '2024-11-16T09:45:49.000000Z', 'handler_name': 'Ambarella AAC'}}], 'input_number': 0}], 'duration': 415.72, 'bitrate': 24234, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1920, 1080], 'video_bitrate': 23988, 'video_fps': 25.0, 'video_rotation': 180.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 192, 'video_duration': 415.72, 'video_n_frames': 10393}
# c:\Users\enesy\AppData\Local\Programs\Python\Python311\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win64-v4.2.2.exe -i C:\Users\enesy\Videos\xd\1.mp4 -loglevel error -f image2pipe -vf scale=1920:1080 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'qt', 'minor_version': '0', 'compatible_brands': 'qt', 'creation_time': '2024-11-16T09:45:49.000000Z', 'com.apple.quicktime.location.accuracy.horizontal': '3.966881', 'com.apple.quicktime.full-frame-rate-playback-intent': '0', 'com.apple.quicktime.location.ISO6709': '+53.1684+008.6545+025.861/', 'com.apple.quicktime.make': 'Apple', 'com.apple.quicktime.model': 'iPhone 15 Pro', 'com.apple.quicktime.software': '18.0.1', 'com.apple.quicktime.creationdate': '2024-11-16T10:45:49+0100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1920, 1080], 'bitrate': 13098, 'fps': 59.96, 'codec_name': 'hevc', 'profile': '(Main 10)', 'metadata': {'creation_time': '2024-11-16T09:45:49.000000Z', 'handler_name': 'Core Media Video', 'encoder': 'HEVC'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 44100, 'bitrate': 179, 'metadata': {'creation_time': '2024-11-16T09:45:49.000000Z', 'handler_name': 'Core Media Audio'}}, {'input_number': 0, 'stream_number': 2, 'stream_type': 'data', 'language': None, 'default': True, 'metadata': {'creation_time': '2024-11-16T09:45:49.000000Z', 'handler_name': 'Core Media Metadata'}}, {'input_number': 0, 'stream_number': 3, 'stream_type': 'data', 'language': None, 'default': True, 'metadata': {'creation_time': '2024-11-16T09:45:49.000000Z', 'handler_name': 'Core Media Metadata'}}, {'input_number': 0, 'stream_number': 4, 'stream_type': 'data', 'language': None, 'default': True, 'metadata': {'creation_time': '2024-11-16T09:45:49.000000Z', 'handler_name': 'Core Media Metadata'}}, {'input_number': 0, 'stream_number': 5, 'stream_type': 'data', 'language': None, 'default': True, 'metadata': {'creation_time': '2024-11-16T09:45:49.000000Z', 'handler_name': 'Core Media Metadata'}}, {'input_number': 0, 'stream_number': 6, 'stream_type': 'data', 'language': None, 'default': True, 'metadata': {'creation_time': '2024-11-16T09:45:49.000000Z', 'handler_name': 'Core Media Metadata'}}], 'input_number': 0}], 'duration': 389.5, 'bitrate': 13460, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'hevc', 'video_profile': '(Main 10)', 'video_size': [1920, 1080], 'video_bitrate': 13098, 'video_fps': 59.96, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 44100, 'audio_bitrate': 179, 'default_data_input_number': 0, 'default_data_stream_number': 6, 'video_duration': 389.5, 'video_n_frames': 23354}
# c:\Users\enesy\AppData\Local\Programs\Python\Python311\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win64-v4.2.2.exe -i C:\Users\enesy\Videos\xd\2.MOV -loglevel error -f image2pipe -vf scale=1920:1080 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'avc1', 'minor_version': '0', 'compatible_brands': 'avc1isom', 'creation_time': '2024-11-16T09:45:51.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1920, 1080], 'bitrate': 25680, 'fps': 29.97002997002997, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'creation_time': '2024-11-16T09:45:51.000000Z', 'handler_name': 'Ambarella AVC', 'encoder': 'Ambarella AVC encoder'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': 'eng', 'default': True, 'fps': 48000, 'bitrate': 192, 'metadata': {'creation_time': '2024-11-16T09:45:51.000000Z', 'handler_name': 'Ambarella AAC'}}], 'input_number': 0}], 'duration': 415.62, 'bitrate': 26261, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1920, 1080], 'video_bitrate': 25680, 'video_fps': 29.97002997002997, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 192, 'video_duration': 415.62, 'video_n_frames': 12456}
# c:\Users\enesy\AppData\Local\Programs\Python\Python311\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win64-v4.2.2.exe -i C:\Users\enesy\Videos\xd\3.mp4 -loglevel error -f image2pipe -vf scale=1920:1080 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '1', 'compatible_brands': 'mp42avc1', 'creation_time': '2024-11-16T11:41:12.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1920, 1080], 'bitrate': 27013, 'fps': 59.94, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'creation_time': '2024-11-16T11:41:12.000000Z'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 125, 'metadata': {'creation_time': '2024-11-16T11:41:12.000000Z'}}], 'input_number': 0}], 'duration': 398.9, 'bitrate': 27149, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1920, 1080], 'video_bitrate': 27013, 'video_fps': 59.94, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 125, 'video_duration': 398.9, 'video_n_frames': 23910}
# c:\Users\enesy\AppData\Local\Programs\Python\Python311\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win64-v4.2.2.exe -i C:\Users\enesy\Videos\xd\4.MP4 -loglevel error -f image2pipe -vf scale=1920:1080 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -

# %%
# Intermediate step, match the longest video with EEG data
import ffmpeg
import pandas as pd
import datetime as dt

video_path = longest_video_path
csv_path = EEG1
video_duration = durations[longest_video_index]

# Extract video creation time
video_metadata = ffmpeg.probe(video_path)
creation_time = video_metadata["streams"][0]["tags"]["creation_time"]
video_creation_dt = dt.datetime.strptime(creation_time, "%Y-%m-%dT%H:%M:%S.%f%z")
video_creation_timestamp = video_creation_dt.timestamp()

# Read the CSV
df = pd.read_csv(csv_path)

# Extract initial timestamp from the CSV
initial_csv_timestamp = df["timestamps"][0]

# Calculate the adjustment needed
time_difference = initial_csv_timestamp - video_creation_timestamp

if time_difference > 0:
    # Video starts later than CSV
    start_time = abs(time_difference)
    end_time = video_duration
else:
    # Video starts earlier or at the same time as CSV
    start_time = 0
    end_time = video_duration - abs(time_difference)

durations[longest_video_index] = (end_time - start_time)

(start_time, end_time)
# Out:
# (83.31299996376038, 415.72)

# %%
# Intermediate step, export the video temporarily.

eeg_sync_video = ffmpeg.input(longest_video_path, ss=start_time, to=end_time)
out = ffmpeg.output(eeg_sync_video, "temporary.mp4").compile()

import subprocess
import datetime # For printing progress
import os

try:
    os.remove("./temporary.mp4")
except FileNotFoundError:
    print("File does not exist, continuing.")

# Run the FFMPEG subprocess
try:
    ffmpeg_process = subprocess.Popen(out, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, universal_newlines=True)
except OSError:
    print("OSError")
except ValueError:
    print("ValueError: Cannot run FFMPEG with given parameters.")

end_time = str(datetime.timedelta(seconds=end_time)) # Used for printing the last point of the video
# Print the progress that ffmpeg outputs
print("FFMPEG is starting, please wait a couple minutes.")
for line in ffmpeg_process.stdout:
    # for all output from ffmpeg
    print(line)

    # If you would like to print it in a simpler format
    # This shows how much of the video you processed
    # if line.startswith("out_time="):
    #     progress = line.split("=")[1]
    #     print(f"Progress: currently at {progress} / going until {end_time}", end="\r")
print("FFMPEG has finished processing.")
# Out:
# FFMPEG is starting, please wait a couple minutes.
# ffmpeg version 2024-05-08-git-e8e84dc325-full_build-www.gyan.dev Copyright (c) 2000-2024 the FFmpeg developers
#
#   built with gcc 13.2.0 (Rev5, Built by MSYS2 project)
#
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#
#   libavutil      59. 17.100 / 59. 17.100
#
#   libavcodec     61.  5.103 / 61.  5.103
#
#   libavformat    61.  3.103 / 61.  3.103
#
#   libavdevice    61.  2.100 / 61.  2.100
#
#   libavfilter    10.  2.101 / 10.  2.101
#
#   libswscale      8.  2.100 /  8.  2.100
#
#   libswresample   5.  2.100 /  5.  2.100
#
#   libpostproc    58.  2.100 / 58.  2.100
#
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'C:\Users\enesy\Videos\xd\1.mp4':
#
#   Metadata:
#
#     major_brand     : avc1
#
#     minor_version   : 0
#
#     compatible_brands: avc1isom
#
#     creation_time   : 2024-11-16T09:45:49.000000Z
#
#   Duration: 00:06:55.72, start: 0.000000, bitrate: 24234 kb/s
#
#   Stream #0:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuvj420p(pc, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 23988 kb/s, 25 fps, 25 tbr, 25k tbn (default)
#
#       Metadata:
#
#         creation_time   : 2024-11-16T09:45:49.000000Z
#
#         handler_name    :  Ambarella AVC
#
#         vendor_id       : [0][0][0][0]
#
#         encoder         : Ambarella AVC encoder
#
#       Side data:
#
#         displaymatrix: rotation of -180.00 degrees
#
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 192 kb/s (default)
#
#       Metadata:
#
#         creation_time   : 2024-11-16T09:45:49.000000Z
#
#         handler_name    :  Ambarella AAC
#
#         vendor_id       : [0][0][0][0]
#
# Stream mapping:
#
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
#
# Press [q] to stop, [?] for help
#
# [libx264 @ 000002c959ab8140] using SAR=1/1
#
# [libx264 @ 000002c959ab8140] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
#
# [libx264 @ 000002c959ab8140] profile High, level 4.0, 4:2:0, 8-bit
#
# [libx264 @ 000002c959ab8140] 264 - core 164 r3190 7ed753b - H.264/MPEG-4 AVC codec - Copyleft 2003-2024 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
#
# Output #0, mp4, to 'temporary.mp4':
#
#   Metadata:
#
#     major_brand     : avc1
#
#     minor_version   : 0
#
#     compatible_brands: avc1isom
#
#     encoder         : Lavf61.3.103
#
#   Stream #0:0(eng): Video: h264 (avc1 / 0x31637661), yuvj420p(pc, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 25 fps, 12800 tbn (default)
#
#       Metadata:
#
#         creation_time   : 2024-11-16T09:45:49.000000Z
#
#         handler_name    :  Ambarella AVC
#
#         vendor_id       : [0][0][0][0]
#
#         encoder         : Lavc61.5.103 libx264
#
#       Side data:
#
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#
#       Metadata:
#
#         creation_time   : 2024-11-16T09:45:49.000000Z
#
#         handler_name    :  Ambarella AAC
#
#         vendor_id       : [0][0][0][0]
#
#         encoder         : Lavc61.5.103 aac
#
# frame=    0 fps=0.0 q=0.0 size=       0KiB time=N/A bitrate=N/A speed=N/A
#
# frame=    0 fps=0.0 q=0.0 size=       0KiB time=N/A bitrate=N/A speed=N/A
#
# frame=    5 fps=3.2 q=28.0 size=       0KiB time=00:00:00.12 bitrate=   3.2kbits/s speed=0.0763x
#
# frame=   17 fps=8.1 q=28.0 size=     256KiB time=00:00:00.60 bitrate=3495.9kbits/s speed=0.287x
#
# frame=   25 fps=9.5 q=28.0 size=     512KiB time=00:00:00.92 bitrate=4559.4kbits/s speed=0.351x
#
# frame=   34 fps= 11 q=28.0 size=     768KiB time=00:00:01.28 bitrate=4915.5kbits/s speed=0.409x
#
# frame=   45 fps= 12 q=28.0 size=    1024KiB time=00:00:01.72 bitrate=4877.3kbits/s speed=0.472x
#
# frame=   56 fps= 13 q=28.0 size=    1280KiB time=00:00:02.16 bitrate=4854.7kbits/s speed=0.517x
#
# frame=   65 fps= 14 q=28.0 size=    1280KiB time=00:00:02.52 bitrate=4161.2kbits/s speed=0.537x
#
# frame=   77 fps= 15 q=28.0 size=    1536KiB time=00:00:03.00 bitrate=4194.4kbits/s speed=0.577x
#
# frame=   89 fps= 16 q=28.0 size=    2048KiB time=00:00:03.48 bitrate=4821.1kbits/s speed=0.609x
#
# frame=   97 fps= 16 q=28.0 size=    2048KiB time=00:00:03.80 bitrate=4415.2kbits/s speed=0.608x
#
# frame=  106 fps= 16 q=28.0 size=    2304KiB time=00:00:04.16 bitrate=4537.2kbits/s speed=0.615x
#
# frame=  113 fps= 16 q=28.0 size=    2560KiB time=00:00:04.44 bitrate=4723.4kbits/s speed=0.61x
#
# frame=  125 fps= 16 q=28.0 size=    2816KiB time=00:00:04.92 bitrate=4688.8kbits/s speed=0.63x
#
# frame=  137 fps= 16 q=28.0 size=    3072KiB time=00:00:05.40 bitrate=4660.4kbits/s speed=0.648x
#
# frame=  149 fps= 17 q=28.0 size=    3328KiB time=00:00:05.88 bitrate=4636.6kbits/s speed=0.665x
#
# frame=  158 fps= 17 q=28.0 size=    3584KiB time=00:00:06.24 bitrate=4705.2kbits/s speed=0.666x
#
# frame=  167 fps= 17 q=28.0 size=    3840KiB time=00:00:06.60 bitrate=4766.3kbits/s speed=0.668x
#
# frame=  181 fps= 17 q=28.0 size=    4096KiB time=00:00:07.16 bitrate=4686.4kbits/s speed=0.688x
#
# frame=  189 fps= 17 q=28.0 size=    4352KiB time=00:00:07.48 bitrate=4766.3kbits/s speed=0.686x
#
# frame=  201 fps= 18 q=28.0 size=    4608KiB time=00:00:07.96 bitrate=4742.4kbits/s speed=0.696x
#
# frame=  210 fps= 18 q=28.0 size=    4608KiB time=00:00:08.32 bitrate=4537.2kbits/s speed=0.697x
#
# frame=  221 fps= 18 q=28.0 size=    4864KiB time=00:00:08.76 bitrate=4548.7kbits/s speed=0.703x
#
# frame=  233 fps= 18 q=28.0 size=    5120KiB time=00:00:09.24 bitrate=4539.3kbits/s speed=0.713x
#
# frame=  245 fps= 18 q=28.0 size=    5376KiB time=00:00:09.72 bitrate=4530.9kbits/s speed=0.72x
#
# frame=  255 fps= 18 q=28.0 size=    5632KiB time=00:00:10.12 bitrate=4559.1kbits/s speed=0.722x
#
# frame=  267 fps= 18 q=28.0 size=    5888KiB time=00:00:10.60 bitrate=4550.5kbits/s speed=0.729x
#
# frame=  279 fps= 19 q=28.0 size=    6144KiB time=00:00:11.08 bitrate=4542.6kbits/s speed=0.736x
#
# frame=  291 fps= 19 q=28.0 size=    6400KiB time=00:00:11.56 bitrate=4535.4kbits/s speed=0.742x
#
# frame=  303 fps= 19 q=28.0 size=    6656KiB time=00:00:12.04 bitrate=4528.8kbits/s speed=0.748x
#
# frame=  315 fps= 19 q=28.0 size=    6912KiB time=00:00:12.52 bitrate=4522.6kbits/s speed=0.754x
#
# frame=  325 fps= 19 q=28.0 size=    7168KiB time=00:00:12.92 bitrate=4544.9kbits/s speed=0.755x
#
# frame=  337 fps= 19 q=28.0 size=    7424KiB time=00:00:13.40 bitrate=4538.6kbits/s speed=0.759x
#
# frame=  349 fps= 19 q=28.0 size=    7424KiB time=00:00:13.88 bitrate=4381.7kbits/s speed=0.764x
#
# frame=  359 fps= 19 q=28.0 size=    7680KiB time=00:00:14.28 bitrate=4405.8kbits/s speed=0.764x
#
# frame=  369 fps= 19 q=28.0 size=    7936KiB time=00:00:14.68 bitrate=4428.6kbits/s speed=0.765x
#
# frame=  380 fps= 19 q=28.0 size=    8192KiB time=00:00:15.12 bitrate=4438.4kbits/s speed=0.767x
#
# frame=  388 fps= 19 q=28.0 size=    8192KiB time=00:00:15.44 bitrate=4346.5kbits/s speed=0.763x
#
# frame=  400 fps= 19 q=28.0 size=    8448KiB time=00:00:15.92 bitrate=4347.1kbits/s speed=0.767x
#
# frame=  412 fps= 19 q=28.0 size=    8704KiB time=00:00:16.40 bitrate=4347.8kbits/s speed=0.771x
#
# frame=  424 fps= 19 q=28.0 size=    9216KiB time=00:00:16.88 bitrate=4472.6kbits/s speed=0.774x
#
# frame=  432 fps= 19 q=28.0 size=    9216KiB time=00:00:17.20 bitrate=4389.4kbits/s speed=0.77x
#
# frame=  442 fps= 19 q=28.0 size=    9728KiB time=00:00:17.60 bitrate=4528.0kbits/s speed=0.77x
#
# frame=  451 fps= 19 q=28.0 size=    9984KiB time=00:00:17.96 bitrate=4554.0kbits/s speed=0.768x
#
# frame=  459 fps= 19 q=28.0 size=   10496KiB time=00:00:18.28 bitrate=4703.7kbits/s speed=0.764x
#
# frame=  470 fps= 19 q=28.0 size=   10752KiB time=00:00:18.72 bitrate=4705.2kbits/s speed=0.766x
#
# frame=  479 fps= 19 q=28.0 size=   11008KiB time=00:00:19.08 bitrate=4726.3kbits/s speed=0.764x
#
# frame=  490 fps= 19 q=28.0 size=   11264KiB time=00:00:19.52 bitrate=4727.2kbits/s speed=0.766x
#
# frame=  498 fps= 19 q=28.0 size=   11520KiB time=00:00:19.84 bitrate=4756.7kbits/s speed=0.763x
#
# frame=  506 fps= 19 q=28.0 size=   11776KiB time=00:00:20.16 bitrate=4785.2kbits/s speed=0.76x
#
# frame=  518 fps= 19 q=28.0 size=   12032KiB time=00:00:20.64 bitrate=4775.5kbits/s speed=0.763x
#
# frame=  530 fps= 19 q=28.0 size=   12544KiB time=00:00:21.12 bitrate=4865.6kbits/s speed=0.766x
#
# frame=  539 fps= 19 q=28.0 size=   12800KiB time=00:00:21.48 bitrate=4881.7kbits/s speed=0.764x
#
# frame=  542 fps= 19 q=28.0 size=   12800KiB time=00:00:21.60 bitrate=4854.5kbits/s speed=0.755x
#
# frame=  551 fps= 19 q=25.0 size=   13056KiB time=00:00:21.96 bitrate=4870.5kbits/s speed=0.754x
#
# frame=  559 fps= 19 q=28.0 size=   13568KiB time=00:00:22.28 bitrate=4988.8kbits/s speed=0.751x
#
# frame=  566 fps= 19 q=28.0 size=   13824KiB time=00:00:22.56 bitrate=5019.8kbits/s speed=0.747x
#
# frame=  576 fps= 19 q=28.0 size=   14336KiB time=00:00:22.96 bitrate=5115.0kbits/s speed=0.748x
#
# frame=  584 fps= 19 q=28.0 size=   14592KiB time=00:00:23.28 bitrate=5134.8kbits/s speed=0.746x
#
# frame=  593 fps= 19 q=28.0 size=   14848KiB time=00:00:23.64 bitrate=5145.3kbits/s speed=0.745x
#
# frame=  602 fps= 19 q=28.0 size=   15360KiB time=00:00:24.00 bitrate=5242.9kbits/s speed=0.744x
#
# frame=  610 fps= 19 q=28.0 size=   15616KiB time=00:00:24.32 bitrate=5260.1kbits/s speed=0.741x
#
# frame=  617 fps= 19 q=28.0 size=   15872KiB time=00:00:24.60 bitrate=5285.5kbits/s speed=0.738x
#
# frame=  630 fps= 19 q=28.0 size=   16384KiB time=00:00:25.12 bitrate=5343.1kbits/s speed=0.742x
#
# frame=  638 fps= 19 q=28.0 size=   16640KiB time=00:00:25.44 bitrate=5358.3kbits/s speed=0.74x
#
# frame=  650 fps= 19 q=28.0 size=   17152KiB time=00:00:25.92 bitrate=5420.9kbits/s speed=0.743x
#
# frame=  654 fps= 18 q=28.0 size=   17408KiB time=00:00:26.08 bitrate=5468.0kbits/s speed=0.736x
#
# frame=  665 fps= 18 q=28.0 size=   17664KiB time=00:00:26.52 bitrate=5456.4kbits/s speed=0.737x
#
# frame=  671 fps= 18 q=28.0 size=   17920KiB time=00:00:26.76 bitrate=5485.8kbits/s speed=0.733x
#
# frame=  679 fps= 18 q=28.0 size=   18176KiB time=00:00:27.08 bitrate=5498.5kbits/s speed=0.732x
#
# frame=  690 fps= 18 q=28.0 size=   18432KiB time=00:00:27.52 bitrate=5486.7kbits/s speed=0.733x
#
# frame=  702 fps= 18 q=28.0 size=   18688KiB time=00:00:28.00 bitrate=5467.6kbits/s speed=0.736x
#
# frame=  710 fps= 18 q=28.0 size=   18944KiB time=00:00:28.32 bitrate=5479.9kbits/s speed=0.734x
#
# frame=  712 fps= 18 q=28.0 size=   18944KiB time=00:00:28.40 bitrate=5464.4kbits/s speed=0.722x
#
# frame=  719 fps= 18 q=28.0 size=   19200KiB time=00:00:28.68 bitrate=5484.2kbits/s speed=0.72x
#
# frame=  726 fps= 18 q=28.0 size=   19200KiB time=00:00:28.96 bitrate=5431.2kbits/s speed=0.717x
#
# frame=  734 fps= 18 q=28.0 size=   19456KiB time=00:00:29.28 bitrate=5443.4kbits/s speed=0.716x
#
# frame=  746 fps= 18 q=28.0 size=   19712KiB time=00:00:29.76 bitrate=5426.1kbits/s speed=0.719x
#
# frame=  758 fps= 18 q=28.0 size=   19968KiB time=00:00:30.24 bitrate=5409.3kbits/s speed=0.721x
#
# frame=  763 fps= 18 q=28.0 size=   19968KiB time=00:00:30.44 bitrate=5373.8kbits/s speed=0.716x
#
# frame=  770 fps= 18 q=28.0 size=   20224KiB time=00:00:30.72 bitrate=5393.1kbits/s speed=0.714x
#
# frame=  785 fps= 18 q=28.0 size=   20480KiB time=00:00:31.32 bitrate=5356.7kbits/s speed=0.719x
#
# frame=  790 fps= 18 q=28.0 size=   20736KiB time=00:00:31.52 bitrate=5389.3kbits/s speed=0.715x
#
# frame=  798 fps= 18 q=28.0 size=   20736KiB time=00:00:31.84 bitrate=5335.1kbits/s speed=0.714x
#
# frame=  809 fps= 18 q=28.0 size=   20992KiB time=00:00:32.28 bitrate=5327.3kbits/s speed=0.715x
#
# frame=  821 fps= 18 q=28.0 size=   21248KiB time=00:00:32.76 bitrate=5313.3kbits/s speed=0.717x
#
# frame=  828 fps= 18 q=28.0 size=   21504KiB time=00:00:33.04 bitrate=5331.8kbits/s speed=0.715x
#
# frame=  837 fps= 18 q=28.0 size=   21504KiB time=00:00:33.40 bitrate=5274.3kbits/s speed=0.715x
#
# frame=  847 fps= 18 q=28.0 size=   21760KiB time=00:00:33.80 bitrate=5273.9kbits/s speed=0.716x
#
# frame=  861 fps= 18 q=28.0 size=   22016KiB time=00:00:34.36 bitrate=5249.0kbits/s speed=0.72x
#
# frame=  872 fps= 18 q=28.0 size=   22272KiB time=00:00:34.80 bitrate=5242.9kbits/s speed=0.721x
#
# frame=  881 fps= 18 q=28.0 size=   22528KiB time=00:00:35.16 bitrate=5248.9kbits/s speed=0.721x
#
# frame=  898 fps= 18 q=28.0 size=   22784KiB time=00:00:35.84 bitrate=5207.8kbits/s speed=0.727x
#
# frame=  907 fps= 18 q=28.0 size=   23040KiB time=00:00:36.20 bitrate=5213.9kbits/s speed=0.726x
#
# frame=  919 fps= 18 q=28.0 size=   23296KiB time=00:00:36.68 bitrate=5202.9kbits/s speed=0.728x
#
# frame=  930 fps= 18 q=28.0 size=   23552KiB time=00:00:37.12 bitrate=5197.7kbits/s speed=0.729x
#
# frame=  941 fps= 18 q=28.0 size=   23808KiB time=00:00:37.56 bitrate=5192.6kbits/s speed=0.731x
#
# frame=  953 fps= 18 q=28.0 size=   23808KiB time=00:00:38.04 bitrate=5127.1kbits/s speed=0.733x
#
# frame=  965 fps= 18 q=28.0 size=   24064KiB time=00:00:38.52 bitrate=5117.7kbits/s speed=0.735x
#
# frame=  977 fps= 18 q=28.0 size=   24576KiB time=00:00:39.00 bitrate=5162.2kbits/s speed=0.736x
#
# frame=  989 fps= 18 q=28.0 size=   24832KiB time=00:00:39.48 bitrate=5152.6kbits/s speed=0.738x
#
# frame= 1001 fps= 19 q=28.0 size=   25088KiB time=00:00:39.96 bitrate=5143.2kbits/s speed=0.74x
#
# frame= 1013 fps= 19 q=28.0 size=   25344KiB time=00:00:40.44 bitrate=5134.0kbits/s speed=0.742x
#
# frame= 1022 fps= 19 q=28.0 size=   25344KiB time=00:00:40.80 bitrate=5088.7kbits/s speed=0.742x
#
# frame= 1034 fps= 19 q=28.0 size=   25600KiB time=00:00:41.28 bitrate=5080.3kbits/s speed=0.743x
#
# frame= 1044 fps= 19 q=28.0 size=   25856KiB time=00:00:41.68 bitrate=5081.9kbits/s speed=0.743x
#
# frame= 1055 fps= 19 q=28.0 size=   25856KiB time=00:00:42.12 bitrate=5028.8kbits/s speed=0.744x
#
# frame= 1069 fps= 19 q=28.0 size=   26112KiB time=00:00:42.68 bitrate=5011.9kbits/s speed=0.747x
#
# frame= 1079 fps= 19 q=28.0 size=   26368KiB time=00:00:43.08 bitrate=5014.1kbits/s speed=0.748x
#
# frame= 1091 fps= 19 q=28.0 size=   26624KiB time=00:00:43.56 bitrate=5007.0kbits/s speed=0.749x
#
# frame= 1099 fps= 19 q=28.0 size=   26624KiB time=00:00:43.88 bitrate=4970.5kbits/s speed=0.748x
#
# frame= 1107 fps= 19 q=28.0 size=   26880KiB time=00:00:44.20 bitrate=4981.9kbits/s speed=0.747x
#
# frame= 1119 fps= 19 q=28.0 size=   27136KiB time=00:00:44.68 bitrate=4975.3kbits/s speed=0.748x
#
# frame= 1131 fps= 19 q=28.0 size=   27136KiB time=00:00:45.16 bitrate=4922.5kbits/s speed=0.75x
#
# frame= 1147 fps= 19 q=28.0 size=   27648KiB time=00:00:45.80 bitrate=4945.3kbits/s speed=0.754x
#
# frame= 1156 fps= 19 q=28.0 size=   27648KiB time=00:00:46.16 bitrate=4906.7kbits/s speed=0.753x
#
# frame= 1167 fps= 19 q=28.0 size=   27904KiB time=00:00:46.60 bitrate=4905.4kbits/s speed=0.754x
#
# frame= 1179 fps= 19 q=28.0 size=   28160KiB time=00:00:47.08 bitrate=4899.9kbits/s speed=0.755x
#
# frame= 1191 fps= 19 q=28.0 size=   28416KiB time=00:00:47.56 bitrate=4894.5kbits/s speed=0.757x
#
# frame= 1203 fps= 19 q=28.0 size=   28416KiB time=00:00:48.04 bitrate=4845.6kbits/s speed=0.758x
#
# frame= 1215 fps= 19 q=28.0 size=   28672KiB time=00:00:48.52 bitrate=4840.9kbits/s speed=0.76x
#
# frame= 1232 fps= 19 q=28.0 size=   28928KiB time=00:00:49.20 bitrate=4816.6kbits/s speed=0.764x
#
# frame= 1247 fps= 19 q=28.0 size=   29184KiB time=00:00:49.80 bitrate=4800.7kbits/s speed=0.767x
#
# frame= 1260 fps= 19 q=28.0 size=   29440KiB time=00:00:50.32 bitrate=4792.8kbits/s speed=0.769x
#
# frame= 1272 fps= 19 q=28.0 size=   29696KiB time=00:00:50.80 bitrate=4788.8kbits/s speed=0.77x
#
# frame= 1284 fps= 19 q=28.0 size=   29696KiB time=00:00:51.28 bitrate=4744.0kbits/s speed=0.771x
#
# frame= 1292 fps= 19 q=28.0 size=   29952KiB time=00:00:51.60 bitrate=4755.2kbits/s speed=0.77x
#
# frame= 1300 fps= 19 q=28.0 size=   29952KiB time=00:00:51.92 bitrate=4725.9kbits/s speed=0.769x
#
# frame= 1312 fps= 19 q=28.0 size=   30208KiB time=00:00:52.40 bitrate=4722.6kbits/s speed=0.77x
#
# frame= 1324 fps= 19 q=28.0 size=   30464KiB time=00:00:52.88 bitrate=4719.4kbits/s speed=0.771x
#
# frame= 1336 fps= 19 q=28.0 size=   30720KiB time=00:00:53.36 bitrate=4716.2kbits/s speed=0.772x
#
# frame= 1348 fps= 19 q=28.0 size=   30720KiB time=00:00:53.84 bitrate=4674.2kbits/s speed=0.774x
#
# frame= 1360 fps= 19 q=28.0 size=   30976KiB time=00:00:54.32 bitrate=4671.5kbits/s speed=0.775x
#
# frame= 1372 fps= 19 q=28.0 size=   31232KiB time=00:00:54.80 bitrate=4668.8kbits/s speed=0.776x
#
# frame= 1384 fps= 19 q=28.0 size=   31488KiB time=00:00:55.28 bitrate=4666.2kbits/s speed=0.777x
#
# frame= 1396 fps= 19 q=28.0 size=   31744KiB time=00:00:55.76 bitrate=4663.7kbits/s speed=0.778x
#
# frame= 1407 fps= 19 q=28.0 size=   32000KiB time=00:00:56.20 bitrate=4664.5kbits/s speed=0.779x
#
# frame= 1420 fps= 20 q=28.0 size=   32000KiB time=00:00:56.72 bitrate=4621.7kbits/s speed=0.78x
#
# frame= 1433 fps= 20 q=28.0 size=   32256KiB time=00:00:57.24 bitrate=4616.4kbits/s speed=0.782x
#
# frame= 1447 fps= 20 q=28.0 size=   32512KiB time=00:00:57.80 bitrate=4607.9kbits/s speed=0.784x
#
# frame= 1455 fps= 20 q=28.0 size=   32768KiB time=00:00:58.12 bitrate=4618.6kbits/s speed=0.783x
#
# frame= 1467 fps= 20 q=28.0 size=   33024KiB time=00:00:58.60 bitrate=4616.6kbits/s speed=0.784x
#
# frame= 1479 fps= 20 q=28.0 size=   33280KiB time=00:00:59.08 bitrate=4614.6kbits/s speed=0.785x
#
# frame= 1491 fps= 20 q=28.0 size=   33536KiB time=00:00:59.56 bitrate=4612.6kbits/s speed=0.786x
#
# frame= 1503 fps= 20 q=28.0 size=   33792KiB time=00:01:00.04 bitrate=4610.7kbits/s speed=0.787x
#
# frame= 1508 fps= 20 q=28.0 size=   33792KiB time=00:01:00.24 bitrate=4595.4kbits/s speed=0.784x
#
# frame= 1515 fps= 20 q=28.0 size=   34048KiB time=00:01:00.52 bitrate=4608.8kbits/s speed=0.782x
#
# frame= 1527 fps= 20 q=28.0 size=   34304KiB time=00:01:01.00 bitrate=4606.9kbits/s speed=0.783x
#
# frame= 1536 fps= 20 q=28.0 size=   34560KiB time=00:01:01.36 bitrate=4614.0kbits/s speed=0.782x
#
# frame= 1543 fps= 20 q=28.0 size=   34560KiB time=00:01:01.64 bitrate=4593.1kbits/s speed=0.781x
#
# frame= 1551 fps= 20 q=28.0 size=   34816KiB time=00:01:01.96 bitrate=4603.2kbits/s speed=0.78x
#
# frame= 1563 fps= 20 q=28.0 size=   35072KiB time=00:01:02.44 bitrate=4601.4kbits/s speed=0.781x
#
# frame= 1575 fps= 20 q=28.0 size=   35072KiB time=00:01:02.92 bitrate=4566.3kbits/s speed=0.782x
#
# frame= 1587 fps= 20 q=28.0 size=   35328KiB time=00:01:03.40 bitrate=4564.8kbits/s speed=0.783x
#
# frame= 1595 fps= 20 q=28.0 size=   35584KiB time=00:01:03.72 bitrate=4574.8kbits/s speed=0.782x
#
# frame= 1607 fps= 20 q=28.0 size=   35840KiB time=00:01:04.20 bitrate=4573.2kbits/s speed=0.782x
#
# frame= 1617 fps= 20 q=28.0 size=   36096KiB time=00:01:04.60 bitrate=4577.4kbits/s speed=0.782x
#
# frame= 1624 fps= 20 q=28.0 size=   36096KiB time=00:01:04.88 bitrate=4557.6kbits/s speed=0.781x
#
# frame= 1638 fps= 20 q=28.0 size=   36352KiB time=00:01:05.44 bitrate=4550.7kbits/s speed=0.782x
#
# frame= 1648 fps= 20 q=28.0 size=   36608KiB time=00:01:05.84 bitrate=4554.9kbits/s speed=0.782x
#
# frame= 1663 fps= 20 q=28.0 size=   37120KiB time=00:01:06.44 bitrate=4576.9kbits/s speed=0.785x
#
# frame= 1676 fps= 20 q=28.0 size=   37120KiB time=00:01:06.96 bitrate=4541.3kbits/s speed=0.786x
#
# frame= 1691 fps= 20 q=28.0 size=   37376KiB time=00:01:07.56 bitrate=4532.0kbits/s speed=0.788x
#
# frame= 1700 fps= 20 q=28.0 size=   37632KiB time=00:01:07.92 bitrate=4538.9kbits/s speed=0.788x
#
# frame= 1708 fps= 20 q=28.0 size=   37632KiB time=00:01:08.24 bitrate=4517.6kbits/s speed=0.787x
#
# frame= 1720 fps= 20 q=28.0 size=   37888KiB time=00:01:08.72 bitrate=4516.6kbits/s speed=0.787x
#
# frame= 1730 fps= 20 q=28.0 size=   38144KiB time=00:01:09.12 bitrate=4520.8kbits/s speed=0.787x
#
# frame= 1736 fps= 20 q=28.0 size=   38400KiB time=00:01:09.36 bitrate=4535.4kbits/s speed=0.785x
#
# frame= 1744 fps= 20 q=28.0 size=   38400KiB time=00:01:09.68 bitrate=4514.5kbits/s speed=0.785x
#
# frame= 1756 fps= 20 q=28.0 size=   38656KiB time=00:01:10.16 bitrate=4513.5kbits/s speed=0.785x
#
# frame= 1765 fps= 20 q=28.0 size=   38912KiB time=00:01:10.52 bitrate=4520.2kbits/s speed=0.785x
#
# frame= 1770 fps= 20 q=28.0 size=   38912KiB time=00:01:10.72 bitrate=4507.5kbits/s speed=0.782x
#
# frame= 1782 fps= 20 q=28.0 size=   39168KiB time=00:01:11.20 bitrate=4506.5kbits/s speed=0.783x
#
# frame= 1792 fps= 20 q=28.0 size=   39424KiB time=00:01:11.60 bitrate=4510.6kbits/s speed=0.783x
#
# frame= 1806 fps= 20 q=28.0 size=   39680KiB time=00:01:12.16 bitrate=4504.7kbits/s speed=0.785x
#
# frame= 1817 fps= 20 q=28.0 size=   39936KiB time=00:01:12.60 bitrate=4506.3kbits/s speed=0.785x
#
# frame= 1830 fps= 20 q=28.0 size=   39936KiB time=00:01:13.12 bitrate=4474.2kbits/s speed=0.786x
#
# frame= 1842 fps= 20 q=28.0 size=   40192KiB time=00:01:13.60 bitrate=4473.5kbits/s speed=0.787x
#
# frame= 1852 fps= 20 q=28.0 size=   40448KiB time=00:01:14.00 bitrate=4477.7kbits/s speed=0.787x
#
# frame= 1864 fps= 20 q=28.0 size=   40704KiB time=00:01:14.48 bitrate=4477.0kbits/s speed=0.788x
#
# frame= 1876 fps= 20 q=28.0 size=   40704KiB time=00:01:14.96 bitrate=4448.3kbits/s speed=0.788x
#
# frame= 1888 fps= 20 q=28.0 size=   40960KiB time=00:01:15.44 bitrate=4447.8kbits/s speed=0.789x
#
# frame= 1902 fps= 20 q=28.0 size=   41472KiB time=00:01:16.00 bitrate=4470.3kbits/s speed=0.79x
#
# frame= 1912 fps= 20 q=28.0 size=   41472KiB time=00:01:16.40 bitrate=4446.8kbits/s speed=0.79x
#
# frame= 1924 fps= 20 q=28.0 size=   41728KiB time=00:01:16.88 bitrate=4446.4kbits/s speed=0.791x
#
# frame= 1936 fps= 20 q=28.0 size=   41984KiB time=00:01:17.36 bitrate=4445.9kbits/s speed=0.791x
#
# frame= 1945 fps= 20 q=28.0 size=   41984KiB time=00:01:17.72 bitrate=4425.3kbits/s speed=0.791x
#
# frame= 1951 fps= 20 q=28.0 size=   42240KiB time=00:01:17.96 bitrate=4438.6kbits/s speed=0.789x
#
# frame= 1960 fps= 20 q=28.0 size=   42240KiB time=00:01:18.32 bitrate=4418.2kbits/s speed=0.789x
#
# frame= 1972 fps= 20 q=28.0 size=   42496KiB time=00:01:18.80 bitrate=4417.9kbits/s speed=0.789x
#
# frame= 1984 fps= 20 q=28.0 size=   42752KiB time=00:01:19.28 bitrate=4417.6kbits/s speed=0.79x
#
# frame= 1994 fps= 20 q=28.0 size=   43008KiB time=00:01:19.68 bitrate=4421.7kbits/s speed=0.79x
#
# frame= 2005 fps= 20 q=28.0 size=   43008KiB time=00:01:20.12 bitrate=4397.4kbits/s speed=0.79x
#
# frame= 2008 fps= 20 q=28.0 size=   43008KiB time=00:01:20.24 bitrate=4390.9kbits/s speed=0.787x
#
# frame= 2020 fps= 20 q=28.0 size=   43264KiB time=00:01:20.72 bitrate=4390.7kbits/s speed=0.788x
#
# frame= 2032 fps= 20 q=28.0 size=   43520KiB time=00:01:21.20 bitrate=4390.6kbits/s speed=0.789x
#
# frame= 2044 fps= 20 q=28.0 size=   43776KiB time=00:01:21.68 bitrate=4390.5kbits/s speed=0.79x
#
# frame= 2056 fps= 20 q=28.0 size=   44032KiB time=00:01:22.16 bitrate=4390.3kbits/s speed=0.79x
#
# frame= 2069 fps= 20 q=28.0 size=   44288KiB time=00:01:22.68 bitrate=4388.1kbits/s speed=0.791x
#
# frame= 2081 fps= 20 q=28.0 size=   44288KiB time=00:01:23.16 bitrate=4362.8kbits/s speed=0.792x
#
# frame= 2093 fps= 20 q=28.0 size=   44544KiB time=00:01:23.64 bitrate=4362.8kbits/s speed=0.793x
#
# frame= 2105 fps= 20 q=28.0 size=   44800KiB time=00:01:24.12 bitrate=4362.8kbits/s speed=0.793x
#
# frame= 2113 fps= 20 q=28.0 size=   44800KiB time=00:01:24.44 bitrate=4346.3kbits/s speed=0.793x
#
# frame= 2125 fps= 20 q=28.0 size=   45056KiB time=00:01:24.92 bitrate=4346.4kbits/s speed=0.793x
#
# frame= 2134 fps= 20 q=28.0 size=   45056KiB time=00:01:25.28 bitrate=4328.1kbits/s speed=0.793x
#
# frame= 2142 fps= 20 q=28.0 size=   45312KiB time=00:01:25.60 bitrate=4336.4kbits/s speed=0.792x
#
# frame= 2159 fps= 20 q=28.0 size=   45568KiB time=00:01:26.28 bitrate=4326.5kbits/s speed=0.794x
#
# frame= 2171 fps= 20 q=28.0 size=   45824KiB time=00:01:26.76 bitrate=4326.8kbits/s speed=0.795x
#
# frame= 2183 fps= 20 q=28.0 size=   46080KiB time=00:01:27.24 bitrate=4327.0kbits/s speed=0.795x
#
# frame= 2191 fps= 20 q=28.0 size=   46080KiB time=00:01:27.56 bitrate=4311.2kbits/s speed=0.794x
#
# frame= 2199 fps= 20 q=28.0 size=   46336KiB time=00:01:27.88 bitrate=4319.4kbits/s speed=0.794x
#
# frame= 2211 fps= 20 q=28.0 size=   46336KiB time=00:01:28.36 bitrate=4295.9kbits/s speed=0.794x
#
# frame= 2223 fps= 20 q=28.0 size=   46592KiB time=00:01:28.84 bitrate=4296.3kbits/s speed=0.795x
#
# frame= 2235 fps= 20 q=28.0 size=   46848KiB time=00:01:29.32 bitrate=4296.7kbits/s speed=0.795x
#
# frame= 2247 fps= 20 q=28.0 size=   47104KiB time=00:01:29.80 bitrate=4297.1kbits/s speed=0.796x
#
# frame= 2259 fps= 20 q=28.0 size=   47360KiB time=00:01:30.28 bitrate=4297.4kbits/s speed=0.796x
#
# frame= 2271 fps= 20 q=28.0 size=   47360KiB time=00:01:30.76 bitrate=4274.7kbits/s speed=0.797x
#
# frame= 2279 fps= 20 q=28.0 size=   47616KiB time=00:01:31.08 bitrate=4282.7kbits/s speed=0.796x
#
# frame= 2290 fps= 20 q=28.0 size=   47616KiB time=00:01:31.52 bitrate=4262.1kbits/s speed=0.796x
#
# frame= 2306 fps= 20 q=28.0 size=   47872KiB time=00:01:32.16 bitrate=4255.3kbits/s speed=0.798x
#
# frame= 2318 fps= 20 q=28.0 size=   48128KiB time=00:01:32.64 bitrate=4255.9kbits/s speed=0.799x
#
# frame= 2330 fps= 20 q=28.0 size=   48384KiB time=00:01:33.12 bitrate=4256.5kbits/s speed=0.799x
#
# frame= 2343 fps= 20 q=28.0 size=   48384KiB time=00:01:33.64 bitrate=4232.8kbits/s speed= 0.8x
#
# frame= 2356 fps= 20 q=28.0 size=   48640KiB time=00:01:34.16 bitrate=4231.7kbits/s speed=0.801x
#
# frame= 2368 fps= 20 q=28.0 size=   48896KiB time=00:01:34.64 bitrate=4232.4kbits/s speed=0.801x
#
# frame= 2380 fps= 20 q=28.0 size=   48896KiB time=00:01:35.12 bitrate=4211.1kbits/s speed=0.802x
#
# frame= 2386 fps= 20 q=25.0 size=   49152KiB time=00:01:35.36 bitrate=4222.5kbits/s speed=0.801x
#
# frame= 2404 fps= 20 q=28.0 size=   49408KiB time=00:01:36.08 bitrate=4212.6kbits/s speed=0.803x
#
# frame= 2417 fps= 20 q=28.0 size=   49664KiB time=00:01:36.60 bitrate=4211.7kbits/s speed=0.804x
#
# frame= 2429 fps= 20 q=28.0 size=   49920KiB time=00:01:37.08 bitrate=4212.5kbits/s speed=0.804x
#
# frame= 2438 fps= 20 q=28.0 size=   49920KiB time=00:01:37.44 bitrate=4196.9kbits/s speed=0.804x
#
# frame= 2449 fps= 20 q=28.0 size=   50176KiB time=00:01:37.88 bitrate=4199.5kbits/s speed=0.804x
#
# frame= 2461 fps= 20 q=28.0 size=   50432KiB time=00:01:38.36 bitrate=4200.3kbits/s speed=0.804x
#
# frame= 2473 fps= 20 q=28.0 size=   50432KiB time=00:01:38.84 bitrate=4179.9kbits/s speed=0.804x
#
# frame= 2481 fps= 20 q=28.0 size=   50688KiB time=00:01:39.16 bitrate=4187.5kbits/s speed=0.804x
#
# frame= 2493 fps= 20 q=28.0 size=   50944KiB time=00:01:39.64 bitrate=4188.4kbits/s speed=0.804x
#
# frame= 2506 fps= 20 q=28.0 size=   50944KiB time=00:01:40.16 bitrate=4166.7kbits/s speed=0.805x
#
# frame= 2514 fps= 20 q=28.0 size=   51200KiB time=00:01:40.48 bitrate=4174.3kbits/s speed=0.804x
#
# frame= 2525 fps= 20 q=28.0 size=   51200KiB time=00:01:40.92 bitrate=4156.1kbits/s speed=0.804x
#
# frame= 2537 fps= 20 q=28.0 size=   51456KiB time=00:01:41.40 bitrate=4157.1kbits/s speed=0.805x
#
# frame= 2549 fps= 20 q=28.0 size=   51712KiB time=00:01:41.88 bitrate=4158.1kbits/s speed=0.805x
#
# frame= 2561 fps= 20 q=28.0 size=   51712KiB time=00:01:42.36 bitrate=4138.6kbits/s speed=0.806x
#
# frame= 2573 fps= 20 q=28.0 size=   51968KiB time=00:01:42.84 bitrate=4139.7kbits/s speed=0.806x
#
# frame= 2585 fps= 20 q=28.0 size=   52224KiB time=00:01:43.32 bitrate=4140.7kbits/s speed=0.807x
#
# frame= 2594 fps= 20 q=28.0 size=   52480KiB time=00:01:43.68 bitrate=4146.6kbits/s speed=0.806x
#
# frame= 2603 fps= 20 q=28.0 size=   52736KiB time=00:01:44.04 bitrate=4152.4kbits/s speed=0.806x
#
# frame= 2610 fps= 20 q=28.0 size=   52992KiB time=00:01:44.32 bitrate=4161.3kbits/s speed=0.805x
#
# frame= 2618 fps= 20 q=28.0 size=   52992KiB time=00:01:44.64 bitrate=4148.6kbits/s speed=0.804x
#
# frame= 2629 fps= 20 q=28.0 size=   53248KiB time=00:01:45.08 bitrate=4151.2kbits/s speed=0.804x
#
# frame= 2639 fps= 20 q=28.0 size=   53760KiB time=00:01:45.48 bitrate=4175.2kbits/s speed=0.804x
#
# frame= 2649 fps= 20 q=28.0 size=   54016KiB time=00:01:45.88 bitrate=4179.3kbits/s speed=0.804x
#
# frame= 2654 fps= 20 q=28.0 size=   54272KiB time=00:01:46.08 bitrate=4191.1kbits/s speed=0.802x
#
# frame= 2666 fps= 20 q=28.0 size=   54528KiB time=00:01:46.56 bitrate=4191.9kbits/s speed=0.803x
#
# frame= 2678 fps= 20 q=28.0 size=   54784KiB time=00:01:47.04 bitrate=4192.7kbits/s speed=0.803x
#
# frame= 2686 fps= 20 q=28.0 size=   55040KiB time=00:01:47.36 bitrate=4199.8kbits/s speed=0.802x
#
# frame= 2695 fps= 20 q=28.0 size=   55296KiB time=00:01:47.72 bitrate=4205.2kbits/s speed=0.802x
#
# frame= 2702 fps= 20 q=28.0 size=   55296KiB time=00:01:48.00 bitrate=4194.3kbits/s speed=0.801x
#
# frame= 2714 fps= 20 q=28.0 size=   55552KiB time=00:01:48.48 bitrate=4195.1kbits/s speed=0.801x
#
# frame= 2724 fps= 20 q=28.0 size=   55808KiB time=00:01:48.88 bitrate=4198.9kbits/s speed=0.801x
#
# frame= 2731 fps= 20 q=25.0 size=   56064KiB time=00:01:49.16 bitrate=4207.4kbits/s speed= 0.8x
#
# frame= 2738 fps= 20 q=28.0 size=   56320KiB time=00:01:49.44 bitrate=4215.8kbits/s speed=0.799x
#
# frame= 2750 fps= 20 q=28.0 size=   56832KiB time=00:01:49.92 bitrate=4235.5kbits/s speed= 0.8x
#
# frame= 2765 fps= 20 q=28.0 size=   57088KiB time=00:01:50.52 bitrate=4231.5kbits/s speed=0.801x
#
# frame= 2767 fps= 20 q=28.0 size=   57088KiB time=00:01:50.60 bitrate=4228.4kbits/s speed=0.799x
#
# frame= 2777 fps= 20 q=28.0 size=   57344KiB time=00:01:51.00 bitrate=4232.1kbits/s speed=0.799x
#
# frame= 2789 fps= 20 q=28.0 size=   57600KiB time=00:01:51.48 bitrate=4232.7kbits/s speed=0.799x
#
# frame= 2801 fps= 20 q=28.0 size=   57856KiB time=00:01:51.96 bitrate=4233.3kbits/s speed=0.799x
#
# frame= 2807 fps= 20 q=28.0 size=   58112KiB time=00:01:52.20 bitrate=4242.9kbits/s speed=0.798x
#
# frame= 2817 fps= 20 q=28.0 size=   58368KiB time=00:01:52.60 bitrate=4246.5kbits/s speed=0.798x
#
# frame= 2825 fps= 20 q=28.0 size=   58624KiB time=00:01:52.92 bitrate=4253.0kbits/s speed=0.797x
#
# frame= 2837 fps= 20 q=28.0 size=   58880KiB time=00:01:53.40 bitrate=4253.5kbits/s speed=0.797x
#
# frame= 2845 fps= 20 q=28.0 size=   59136KiB time=00:01:53.72 bitrate=4260.0kbits/s speed=0.797x
#
# frame= 2853 fps= 20 q=28.0 size=   59392KiB time=00:01:54.04 bitrate=4266.4kbits/s speed=0.796x
#
# frame= 2862 fps= 20 q=28.0 size=   59392KiB time=00:01:54.40 bitrate=4253.0kbits/s speed=0.796x
#
# frame= 2873 fps= 20 q=28.0 size=   59648KiB time=00:01:54.84 bitrate=4254.9kbits/s speed=0.796x
#
# frame= 2880 fps= 20 q=28.0 size=   59904KiB time=00:01:55.12 bitrate=4262.8kbits/s speed=0.795x
#
# frame= 2887 fps= 20 q=28.0 size=   60160KiB time=00:01:55.40 bitrate=4270.6kbits/s speed=0.794x
#
# frame= 2898 fps= 20 q=28.0 size=   60416KiB time=00:01:55.84 bitrate=4272.5kbits/s speed=0.794x
#
# frame= 2905 fps= 20 q=28.0 size=   60672KiB time=00:01:56.12 bitrate=4280.3kbits/s speed=0.793x
#
# frame= 2914 fps= 20 q=28.0 size=   60928KiB time=00:01:56.48 bitrate=4285.0kbits/s speed=0.793x
#
# frame= 2926 fps= 20 q=28.0 size=   61184KiB time=00:01:56.96 bitrate=4285.4kbits/s speed=0.793x
#
# frame= 2934 fps= 20 q=28.0 size=   61440KiB time=00:01:57.28 bitrate=4291.6kbits/s speed=0.793x
#
# frame= 2942 fps= 20 q=28.0 size=   61440KiB time=00:01:57.60 bitrate=4279.9kbits/s speed=0.792x
#
# frame= 2954 fps= 20 q=28.0 size=   61696KiB time=00:01:58.08 bitrate=4280.3kbits/s speed=0.792x
#
# frame= 2962 fps= 20 q=28.0 size=   61952KiB time=00:01:58.40 bitrate=4286.4kbits/s speed=0.792x
#
# frame= 2971 fps= 20 q=28.0 size=   62464KiB time=00:01:58.76 bitrate=4308.7kbits/s speed=0.791x
#
# frame= 2978 fps= 20 q=28.0 size=   62464KiB time=00:01:59.04 bitrate=4298.6kbits/s speed=0.791x
#
# frame= 2990 fps= 20 q=28.0 size=   62976KiB time=00:01:59.52 bitrate=4316.4kbits/s speed=0.791x
#
# frame= 3000 fps= 20 q=28.0 size=   63232KiB time=00:01:59.92 bitrate=4319.5kbits/s speed=0.791x
#
# frame= 3007 fps= 20 q=28.0 size=   63488KiB time=00:02:00.20 bitrate=4326.9kbits/s speed=0.79x
#
# frame= 3014 fps= 20 q=28.0 size=   63488KiB time=00:02:00.48 bitrate=4316.8kbits/s speed=0.789x
#
# frame= 3026 fps= 20 q=28.0 size=   63744KiB time=00:02:00.96 bitrate=4317.1kbits/s speed=0.79x
#
# frame= 3038 fps= 20 q=28.0 size=   64000KiB time=00:02:01.44 bitrate=4317.3kbits/s speed=0.79x
#
# frame= 3043 fps= 20 q=28.0 size=   64256KiB time=00:02:01.64 bitrate=4327.4kbits/s speed=0.789x
#
# frame= 3051 fps= 20 q=28.0 size=   64512KiB time=00:02:01.96 bitrate=4333.2kbits/s speed=0.788x
#
# frame= 3062 fps= 20 q=28.0 size=   64768KiB time=00:02:02.40 bitrate=4334.8kbits/s speed=0.788x
#
# frame= 3074 fps= 20 q=28.0 size=   65024KiB time=00:02:02.88 bitrate=4334.9kbits/s speed=0.789x
#
# frame= 3086 fps= 20 q=28.0 size=   65280KiB time=00:02:03.36 bitrate=4335.1kbits/s speed=0.789x
#
# frame= 3098 fps= 20 q=28.0 size=   65536KiB time=00:02:03.84 bitrate=4335.2kbits/s speed=0.79x
#
# frame= 3110 fps= 20 q=28.0 size=   65792KiB time=00:02:04.32 bitrate=4335.3kbits/s speed=0.79x
#
# frame= 3122 fps= 20 q=28.0 size=   66048KiB time=00:02:04.80 bitrate=4335.5kbits/s speed=0.791x
#
# frame= 3127 fps= 20 q=28.0 size=   66048KiB time=00:02:05.00 bitrate=4328.5kbits/s speed=0.789x
#
# frame= 3134 fps= 20 q=28.0 size=   66304KiB time=00:02:05.28 bitrate=4335.6kbits/s speed=0.788x
#
# frame= 3146 fps= 20 q=28.0 size=   66560KiB time=00:02:05.76 bitrate=4335.7kbits/s speed=0.789x
#
# frame= 3156 fps= 20 q=28.0 size=   66816KiB time=00:02:06.16 bitrate=4338.6kbits/s speed=0.789x
#
# frame= 3166 fps= 20 q=28.0 size=   67072KiB time=00:02:06.56 bitrate=4341.5kbits/s speed=0.788x
#
# frame= 3178 fps= 20 q=28.0 size=   67072KiB time=00:02:07.04 bitrate=4325.0kbits/s speed=0.789x
#
# frame= 3186 fps= 20 q=28.0 size=   67328KiB time=00:02:07.36 bitrate=4330.6kbits/s speed=0.788x
#
# frame= 3198 fps= 20 q=28.0 size=   67584KiB time=00:02:07.84 bitrate=4330.8kbits/s speed=0.789x
#
# frame= 3210 fps= 20 q=28.0 size=   67584KiB time=00:02:08.32 bitrate=4314.6kbits/s speed=0.789x
#
# frame= 3224 fps= 20 q=28.0 size=   67840KiB time=00:02:08.88 bitrate=4312.1kbits/s speed=0.79x
#
# frame= 3233 fps= 20 q=28.0 size=   68096KiB time=00:02:09.24 bitrate=4316.3kbits/s speed=0.79x
#
# frame= 3246 fps= 20 q=28.0 size=   68352KiB time=00:02:09.76 bitrate=4315.2kbits/s speed=0.791x
#
# frame= 3257 fps= 20 q=28.0 size=   68352KiB time=00:02:10.20 bitrate=4300.6kbits/s speed=0.791x
#
# frame= 3269 fps= 20 q=28.0 size=   68608KiB time=00:02:10.68 bitrate=4300.9kbits/s speed=0.791x
#
# frame= 3279 fps= 20 q=28.0 size=   68864KiB time=00:02:11.08 bitrate=4303.7kbits/s speed=0.791x
#
# frame= 3283 fps= 20 q=28.0 size=   68864KiB time=00:02:11.24 bitrate=4298.5kbits/s speed=0.79x
#
# frame= 3294 fps= 20 q=28.0 size=   69120KiB time=00:02:11.68 bitrate=4300.1kbits/s speed=0.79x
#
# frame= 3305 fps= 20 q=28.0 size=   69632KiB time=00:02:12.12 bitrate=4317.5kbits/s speed=0.79x
#
# frame= 3316 fps= 20 q=28.0 size=   69888KiB time=00:02:12.56 bitrate=4319.0kbits/s speed=0.79x
#
# frame= 3328 fps= 20 q=28.0 size=   70144KiB time=00:02:13.04 bitrate=4319.2kbits/s speed=0.79x
#
# frame= 3340 fps= 20 q=28.0 size=   70400KiB time=00:02:13.52 bitrate=4319.3kbits/s speed=0.791x
#
# frame= 3347 fps= 20 q=28.0 size=   70400KiB time=00:02:13.80 bitrate=4310.3kbits/s speed=0.79x
#
# frame= 3353 fps= 20 q=28.0 size=   70656KiB time=00:02:14.04 bitrate=4318.2kbits/s speed=0.789x
#
# frame= 3364 fps= 20 q=28.0 size=   70912KiB time=00:02:14.48 bitrate=4319.7kbits/s speed=0.789x
#
# frame= 3374 fps= 20 q=28.0 size=   71168KiB time=00:02:14.88 bitrate=4322.4kbits/s speed=0.789x
#
# frame= 3383 fps= 20 q=28.0 size=   71424KiB time=00:02:15.24 bitrate=4326.4kbits/s speed=0.789x
#
# frame= 3390 fps= 20 q=28.0 size=   71680KiB time=00:02:15.52 bitrate=4333.0kbits/s speed=0.788x
#
# frame= 3402 fps= 20 q=28.0 size=   71936KiB time=00:02:16.00 bitrate=4333.1kbits/s speed=0.788x
#
# frame= 3411 fps= 20 q=28.0 size=   72192KiB time=00:02:16.36 bitrate=4337.0kbits/s speed=0.788x
#
# frame= 3418 fps= 20 q=28.0 size=   72192KiB time=00:02:16.64 bitrate=4328.1kbits/s speed=0.787x
#
# frame= 3424 fps= 20 q=28.0 size=   72448KiB time=00:02:16.88 bitrate=4335.9kbits/s speed=0.786x
#
# frame= 3435 fps= 20 q=28.0 size=   72704KiB time=00:02:17.32 bitrate=4337.3kbits/s speed=0.786x
#
# frame= 3442 fps= 20 q=28.0 size=   72960KiB time=00:02:17.60 bitrate=4343.7kbits/s speed=0.786x
#
# frame= 3447 fps= 20 q=28.0 size=   73216KiB time=00:02:17.80 bitrate=4352.6kbits/s speed=0.784x
#
# frame= 3458 fps= 20 q=28.0 size=   73472KiB time=00:02:18.24 bitrate=4353.9kbits/s speed=0.784x
#
# frame= 3466 fps= 20 q=28.0 size=   73728KiB time=00:02:18.56 bitrate=4359.0kbits/s speed=0.784x
#
# frame= 3476 fps= 20 q=28.0 size=   73984KiB time=00:02:18.92 bitrate=4362.8kbits/s speed=0.784x
#
# frame= 3482 fps= 20 q=28.0 size=   73984KiB time=00:02:19.20 bitrate=4354.0kbits/s speed=0.783x
#
# frame= 3494 fps= 20 q=28.0 size=   74240KiB time=00:02:19.68 bitrate=4354.1kbits/s speed=0.783x
#
# frame= 3506 fps= 20 q=28.0 size=   74496KiB time=00:02:20.16 bitrate=4354.1kbits/s speed=0.783x
#
# frame= 3515 fps= 20 q=28.0 size=   75008KiB time=00:02:20.52 bitrate=4372.8kbits/s speed=0.783x
#
# frame= 3527 fps= 20 q=28.0 size=   75264KiB time=00:02:21.00 bitrate=4372.8kbits/s speed=0.784x
#
# frame= 3531 fps= 20 q=28.0 size=   75264KiB time=00:02:21.16 bitrate=4367.8kbits/s speed=0.782x
#
# frame= 3543 fps= 20 q=28.0 size=   75520KiB time=00:02:21.64 bitrate=4367.8kbits/s speed=0.783x
#
# frame= 3555 fps= 20 q=28.0 size=   75776KiB time=00:02:22.12 bitrate=4367.8kbits/s speed=0.783x
#
# frame= 3567 fps= 20 q=28.0 size=   76032KiB time=00:02:22.60 bitrate=4367.8kbits/s speed=0.783x
#
# frame= 3579 fps= 20 q=28.0 size=   76288KiB time=00:02:23.08 bitrate=4367.8kbits/s speed=0.784x
#
# frame= 3586 fps= 20 q=28.0 size=   76544KiB time=00:02:23.36 bitrate=4373.9kbits/s speed=0.783x
#
# frame= 3596 fps= 20 q=28.0 size=   76800KiB time=00:02:23.76 bitrate=4376.4kbits/s speed=0.783x
#
# frame= 3608 fps= 20 q=28.0 size=   77312KiB time=00:02:24.24 bitrate=4390.9kbits/s speed=0.783x
#
# frame= 3619 fps= 20 q=28.0 size=   77312KiB time=00:02:24.68 bitrate=4377.5kbits/s speed=0.783x
#
# frame= 3631 fps= 20 q=28.0 size=   77568KiB time=00:02:25.16 bitrate=4377.5kbits/s speed=0.784x
#
# frame= 3639 fps= 20 q=28.0 size=   77824KiB time=00:02:25.48 bitrate=4382.3kbits/s speed=0.783x
#
# frame= 3651 fps= 20 q=28.0 size=   78080KiB time=00:02:25.96 bitrate=4382.2kbits/s speed=0.784x
#
# frame= 3663 fps= 20 q=28.0 size=   78080KiB time=00:02:26.44 bitrate=4367.9kbits/s speed=0.784x
#
# frame= 3674 fps= 20 q=28.0 size=   78336KiB time=00:02:26.88 bitrate=4369.1kbits/s speed=0.784x
#
# frame= 3684 fps= 20 q=28.0 size=   78592KiB time=00:02:27.28 bitrate=4371.4kbits/s speed=0.784x
#
# frame= 3692 fps= 20 q=28.0 size=   78848KiB time=00:02:27.60 bitrate=4376.2kbits/s speed=0.784x
#
# frame= 3698 fps= 20 q=28.0 size=   79104KiB time=00:02:27.84 bitrate=4383.3kbits/s speed=0.783x
#
# frame= 3710 fps= 20 q=28.0 size=   79360KiB time=00:02:28.32 bitrate=4383.2kbits/s speed=0.783x
#
# frame= 3719 fps= 20 q=28.0 size=   79616KiB time=00:02:28.68 bitrate=4386.7kbits/s speed=0.783x
#
# frame= 3730 fps= 20 q=28.0 size=   79872KiB time=00:02:29.12 bitrate=4387.8kbits/s speed=0.783x
#
# frame= 3738 fps= 20 q=28.0 size=   80128KiB time=00:02:29.44 bitrate=4392.5kbits/s speed=0.782x
#
# frame= 3746 fps= 20 q=28.0 size=   80384KiB time=00:02:29.76 bitrate=4397.1kbits/s speed=0.782x
#
# frame= 3758 fps= 20 q=28.0 size=   80640KiB time=00:02:30.24 bitrate=4397.0kbits/s speed=0.782x
#
# frame= 3768 fps= 20 q=28.0 size=   80896KiB time=00:02:30.64 bitrate=4399.2kbits/s speed=0.782x
#
# frame= 3774 fps= 20 q=28.0 size=   81152KiB time=00:02:30.88 bitrate=4406.1kbits/s speed=0.781x
#
# frame= 3782 fps= 20 q=28.0 size=   81408KiB time=00:02:31.20 bitrate=4410.7kbits/s speed=0.781x
#
# frame= 3794 fps= 20 q=28.0 size=   81664KiB time=00:02:31.68 bitrate=4410.5kbits/s speed=0.781x
#
# frame= 3804 fps= 20 q=28.0 size=   81920KiB time=00:02:32.08 bitrate=4412.7kbits/s speed=0.781x
#
# frame= 3814 fps= 20 q=28.0 size=   82176KiB time=00:02:32.48 bitrate=4414.9kbits/s speed=0.781x
#
# frame= 3818 fps= 20 q=28.0 size=   82176KiB time=00:02:32.64 bitrate=4410.3kbits/s speed=0.78x
#
# frame= 3830 fps= 20 q=28.0 size=   82688KiB time=00:02:33.12 bitrate=4423.9kbits/s speed=0.78x
#
# frame= 3842 fps= 20 q=28.0 size=   82944KiB time=00:02:33.60 bitrate=4423.7kbits/s speed=0.781x
#
# frame= 3848 fps= 20 q=28.0 size=   83200KiB time=00:02:33.84 bitrate=4430.4kbits/s speed=0.78x
#
# frame= 3854 fps= 19 q=28.0 size=   83456KiB time=00:02:34.08 bitrate=4437.1kbits/s speed=0.779x
#
# frame= 3866 fps= 19 q=28.0 size=   83712KiB time=00:02:34.56 bitrate=4436.9kbits/s speed=0.779x
#
# frame= 3876 fps= 19 q=28.0 size=   83968KiB time=00:02:34.96 bitrate=4439.0kbits/s speed=0.779x
#
# frame= 3887 fps= 19 q=28.0 size=   84224KiB time=00:02:35.40 bitrate=4439.9kbits/s speed=0.779x
#
# frame= 3892 fps= 19 q=28.0 size=   84224KiB time=00:02:35.60 bitrate=4434.2kbits/s speed=0.778x
#
# frame= 3901 fps= 19 q=28.0 size=   84480KiB time=00:02:35.96 bitrate=4437.4kbits/s speed=0.778x
#
# frame= 3910 fps= 19 q=28.0 size=   84992KiB time=00:02:36.32 bitrate=4454.0kbits/s speed=0.778x
#
# frame= 3916 fps= 19 q=28.0 size=   84992KiB time=00:02:36.56 bitrate=4447.2kbits/s speed=0.777x
#
# frame= 3928 fps= 19 q=28.0 size=   85504KiB time=00:02:37.04 bitrate=4460.3kbits/s speed=0.778x
#
# frame= 3938 fps= 19 q=28.0 size=   85760KiB time=00:02:37.44 bitrate=4462.3kbits/s speed=0.777x
#
# frame= 3945 fps= 19 q=28.0 size=   86016KiB time=00:02:37.72 bitrate=4467.7kbits/s speed=0.777x
#
# frame= 3954 fps= 19 q=28.0 size=   86016KiB time=00:02:38.08 bitrate=4457.5kbits/s speed=0.777x
#
# frame= 3964 fps= 19 q=28.0 size=   86272KiB time=00:02:38.48 bitrate=4459.5kbits/s speed=0.777x
#
# frame= 3971 fps= 19 q=28.0 size=   86528KiB time=00:02:38.76 bitrate=4464.8kbits/s speed=0.776x
#
# frame= 3978 fps= 19 q=28.0 size=   86528KiB time=00:02:39.04 bitrate=4457.0kbits/s speed=0.775x
#
# frame= 3989 fps= 19 q=28.0 size=   87040KiB time=00:02:39.48 bitrate=4471.0kbits/s speed=0.776x
#
# frame= 4001 fps= 19 q=28.0 size=   87552KiB time=00:02:39.96 bitrate=4483.8kbits/s speed=0.776x
#
# frame= 4012 fps= 19 q=28.0 size=   87808KiB time=00:02:40.40 bitrate=4484.6kbits/s speed=0.776x
#
# frame= 4022 fps= 19 q=28.0 size=   88064KiB time=00:02:40.80 bitrate=4486.4kbits/s speed=0.776x
#
# frame= 4026 fps= 19 q=28.0 size=   88064KiB time=00:02:40.96 bitrate=4482.0kbits/s speed=0.775x
#
# frame= 4038 fps= 19 q=28.0 size=   88320KiB time=00:02:41.44 bitrate=4481.7kbits/s speed=0.775x
#
# frame= 4046 fps= 19 q=28.0 size=   88576KiB time=00:02:41.76 bitrate=4485.8kbits/s speed=0.775x
#
# frame= 4057 fps= 19 q=28.0 size=   88832KiB time=00:02:42.20 bitrate=4486.5kbits/s speed=0.775x
#
# frame= 4064 fps= 19 q=28.0 size=   89088KiB time=00:02:42.48 bitrate=4491.7kbits/s speed=0.774x
#
# frame= 4074 fps= 19 q=28.0 size=   89344KiB time=00:02:42.88 bitrate=4493.5kbits/s speed=0.774x
#
# frame= 4084 fps= 19 q=28.0 size=   89600KiB time=00:02:43.28 bitrate=4495.4kbits/s speed=0.774x
#
# frame= 4092 fps= 19 q=28.0 size=   89856KiB time=00:02:43.60 bitrate=4499.4kbits/s speed=0.774x
#
# frame= 4104 fps= 19 q=28.0 size=   90112KiB time=00:02:44.08 bitrate=4499.0kbits/s speed=0.774x
#
# frame= 4113 fps= 19 q=28.0 size=   90368KiB time=00:02:44.44 bitrate=4501.9kbits/s speed=0.774x
#
# frame= 4120 fps= 19 q=28.0 size=   90624KiB time=00:02:44.72 bitrate=4507.0kbits/s speed=0.773x
#
# frame= 4132 fps= 19 q=28.0 size=   90880KiB time=00:02:45.20 bitrate=4506.6kbits/s speed=0.774x
#
# frame= 4138 fps= 19 q=28.0 size=   91136KiB time=00:02:45.44 bitrate=4512.7kbits/s speed=0.773x
#
# frame= 4150 fps= 19 q=28.0 size=   91648KiB time=00:02:45.92 bitrate=4525.0kbits/s speed=0.773x
#
# frame= 4158 fps= 19 q=28.0 size=   91648KiB time=00:02:46.24 bitrate=4516.2kbits/s speed=0.773x
#
# frame= 4169 fps= 19 q=28.0 size=   91904KiB time=00:02:46.68 bitrate=4516.9kbits/s speed=0.773x
#
# frame= 4178 fps= 19 q=28.0 size=   92160KiB time=00:02:47.04 bitrate=4519.7kbits/s speed=0.773x
#
# frame= 4190 fps= 19 q=28.0 size=   92416KiB time=00:02:47.52 bitrate=4519.3kbits/s speed=0.773x
#
# frame= 4202 fps= 19 q=28.0 size=   92672KiB time=00:02:48.00 bitrate=4518.9kbits/s speed=0.773x
#
# frame= 4212 fps= 19 q=28.0 size=   92928KiB time=00:02:48.40 bitrate=4520.6kbits/s speed=0.774x
#
# frame= 4222 fps= 19 q=28.0 size=   93184KiB time=00:02:48.80 bitrate=4522.3kbits/s speed=0.774x
#
# frame= 4230 fps= 19 q=28.0 size=   93184KiB time=00:02:49.12 bitrate=4513.7kbits/s speed=0.773x
#
# frame= 4238 fps= 19 q=28.0 size=   93440KiB time=00:02:49.44 bitrate=4517.6kbits/s speed=0.773x
#
# frame= 4250 fps= 19 q=28.0 size=   93696KiB time=00:02:49.92 bitrate=4517.2kbits/s speed=0.773x
#
# frame= 4262 fps= 19 q=28.0 size=   93952KiB time=00:02:50.40 bitrate=4516.8kbits/s speed=0.774x
#
# frame= 4274 fps= 19 q=28.0 size=   94208KiB time=00:02:50.88 bitrate=4516.3kbits/s speed=0.774x
#
# frame= 4283 fps= 19 q=28.0 size=   94464KiB time=00:02:51.24 bitrate=4519.1kbits/s speed=0.774x
#
# frame= 4289 fps= 19 q=28.0 size=   94720KiB time=00:02:51.48 bitrate=4525.0kbits/s speed=0.773x
#
# ...
#
# frame= 4883 fps= 19 q=28.0 size=  109824KiB time=00:03:15.24 bitrate=4608.1kbits/s speed=0.768x
#
# frame= 4890 fps= 19 q=28.0 size=  109824KiB time=00:03:15.52 bitrate=4601.5kbits/s speed=0.767x
#
# frame= 4901 fps= 19 q=28.0 size=  110080KiB time=00:03:15.96 bitrate=4601.8kbits/s speed=0.767x
#
# frame= 4911 fps= 19 q=28.0 size=  110336KiB time=00:03:16.36 bitrate=4603.1kbits/s speed=0.767x
#
# frame= 4917 fps= 19 q=28.0 size=  110592KiB time=00:03:16.60 bitrate=4608.2kbits/s speed=0.767x
#
# frame= 4929 fps= 19 q=28.0 size=  110848KiB time=00:03:17.04 bitrate=4608.5kbits/s speed=0.767x
#
# frame= 4940 fps= 19 q=28.0 size=  111360KiB time=00:03:17.52 bitrate=4618.6kbits/s speed=0.767x
#
# frame= 4951 fps= 19 q=28.0 size=  111616KiB time=00:03:17.96 bitrate=4618.9kbits/s speed=0.767x
#
# frame= 4959 fps= 19 q=28.0 size=  111872KiB time=00:03:18.28 bitrate=4622.0kbits/s speed=0.767x
#
# frame= 4971 fps= 19 q=28.0 size=  112128KiB time=00:03:18.76 bitrate=4621.4kbits/s speed=0.767x
#
# frame= 4983 fps= 19 q=28.0 size=  112384KiB time=00:03:19.24 bitrate=4620.8kbits/s speed=0.768x
#
# frame= 4995 fps= 19 q=28.0 size=  112640KiB time=00:03:19.72 bitrate=4620.2kbits/s speed=0.768x
#
# frame= 5003 fps= 19 q=28.0 size=  112896KiB time=00:03:20.04 bitrate=4623.3kbits/s speed=0.768x
#
# frame= 5014 fps= 19 q=28.0 size=  113152KiB time=00:03:20.48 bitrate=4623.6kbits/s speed=0.768x
#
# frame= 5022 fps= 19 q=28.0 size=  113408KiB time=00:03:20.80 bitrate=4626.7kbits/s speed=0.768x
#
# frame= 5034 fps= 19 q=28.0 size=  113664KiB time=00:03:21.28 bitrate=4626.1kbits/s speed=0.768x
#
# frame= 5042 fps= 19 q=28.0 size=  113920KiB time=00:03:21.60 bitrate=4629.1kbits/s speed=0.767x
#
# frame= 5054 fps= 19 q=28.0 size=  114176KiB time=00:03:22.08 bitrate=4628.5kbits/s speed=0.768x
#
# frame= 5062 fps= 19 q=28.0 size=  114432KiB time=00:03:22.40 bitrate=4631.6kbits/s speed=0.768x
#
# frame= 5067 fps= 19 q=28.0 size=  114688KiB time=00:03:22.60 bitrate=4637.3kbits/s speed=0.767x
#
# frame= 5078 fps= 19 q=28.0 size=  114944KiB time=00:03:23.04 bitrate=4637.6kbits/s speed=0.767x
#
# frame= 5090 fps= 19 q=28.0 size=  115200KiB time=00:03:23.52 bitrate=4637.0kbits/s speed=0.767x
#
# frame= 5096 fps= 19 q=28.0 size=  115456KiB time=00:03:23.76 bitrate=4641.8kbits/s speed=0.767x
#
# frame= 5103 fps= 19 q=28.0 size=  115712KiB time=00:03:24.04 bitrate=4645.7kbits/s speed=0.766x
#
# frame= 5114 fps= 19 q=28.0 size=  115968KiB time=00:03:24.48 bitrate=4646.0kbits/s speed=0.766x
#
# frame= 5126 fps= 19 q=28.0 size=  116224KiB time=00:03:24.96 bitrate=4645.3kbits/s speed=0.767x
#
# frame= 5138 fps= 19 q=28.0 size=  116480KiB time=00:03:25.44 bitrate=4644.7kbits/s speed=0.767x
#
# frame= 5138 fps= 19 q=28.0 size=  116480KiB time=00:03:25.44 bitrate=4644.7kbits/s speed=0.765x
#
# frame= 5150 fps= 19 q=28.0 size=  116736KiB time=00:03:25.92 bitrate=4644.0kbits/s speed=0.766x
#
# frame= 5158 fps= 19 q=28.0 size=  117248KiB time=00:03:26.24 bitrate=4657.2kbits/s speed=0.765x
#
# frame= 5162 fps= 19 q=28.0 size=  117248KiB time=00:03:26.40 bitrate=4653.6kbits/s speed=0.765x
#
# frame= 5174 fps= 19 q=28.0 size=  117504KiB time=00:03:26.88 bitrate=4652.9kbits/s speed=0.765x
#
# frame= 5183 fps= 19 q=28.0 size=  117760KiB time=00:03:27.24 bitrate=4654.9kbits/s speed=0.765x
#
# frame= 5187 fps= 19 q=28.0 size=  118016KiB time=00:03:27.40 bitrate=4661.5kbits/s speed=0.764x
#
# frame= 5198 fps= 19 q=28.0 size=  118272KiB time=00:03:27.84 bitrate=4661.7kbits/s speed=0.764x
#
# frame= 5210 fps= 19 q=28.0 size=  118272KiB time=00:03:28.32 bitrate=4650.9kbits/s speed=0.764x
#
# frame= 5214 fps= 19 q=28.0 size=  118528KiB time=00:03:28.48 bitrate=4657.4kbits/s speed=0.763x
#
# frame= 5226 fps= 19 q=28.0 size=  118784KiB time=00:03:28.96 bitrate=4656.8kbits/s speed=0.764x
#
# frame= 5237 fps= 19 q=28.0 size=  119296KiB time=00:03:29.40 bitrate=4667.0kbits/s speed=0.764x
#
# frame= 5244 fps= 19 q=28.0 size=  119552KiB time=00:03:29.68 bitrate=4670.8kbits/s speed=0.763x
#
# frame= 5253 fps= 19 q=28.0 size=  119808KiB time=00:03:30.04 bitrate=4672.8kbits/s speed=0.763x
#
# frame= 5261 fps= 19 q=28.0 size=  120064KiB time=00:03:30.36 bitrate=4675.6kbits/s speed=0.763x
#
# frame= 5273 fps= 19 q=28.0 size=  120320KiB time=00:03:30.84 bitrate=4674.9kbits/s speed=0.763x
#
# frame= 5285 fps= 19 q=28.0 size=  120320KiB time=00:03:31.32 bitrate=4664.3kbits/s speed=0.764x
#
# frame= 5297 fps= 19 q=28.0 size=  120576KiB time=00:03:31.80 bitrate=4663.6kbits/s speed=0.764x
#
# frame= 5304 fps= 19 q=28.0 size=  120832KiB time=00:03:32.08 bitrate=4667.4kbits/s speed=0.763x
#
# frame= 5314 fps= 19 q=28.0 size=  120832KiB time=00:03:32.48 bitrate=4658.6kbits/s speed=0.763x
#
# frame= 5325 fps= 19 q=28.0 size=  121088KiB time=00:03:32.92 bitrate=4658.8kbits/s speed=0.763x
#
# frame= 5333 fps= 19 q=28.0 size=  121344KiB time=00:03:33.24 bitrate=4661.7kbits/s speed=0.763x
#
# frame= 5345 fps= 19 q=28.0 size=  121344KiB time=00:03:33.72 bitrate=4651.2kbits/s speed=0.763x
#
# frame= 5357 fps= 19 q=28.0 size=  121600KiB time=00:03:34.20 bitrate=4650.5kbits/s speed=0.764x
#
# frame= 5361 fps= 19 q=28.0 size=  121856KiB time=00:03:34.36 bitrate=4656.9kbits/s speed=0.763x
#
# frame= 5370 fps= 19 q=28.0 size=  122112KiB time=00:03:34.72 bitrate=4658.8kbits/s speed=0.763x
#
# frame= 5381 fps= 19 q=28.0 size=  122368KiB time=00:03:35.16 bitrate=4659.0kbits/s speed=0.763x
#
# frame= 5393 fps= 19 q=28.0 size=  122624KiB time=00:03:35.64 bitrate=4658.4kbits/s speed=0.763x
#
# frame= 5401 fps= 19 q=28.0 size=  122880KiB time=00:03:35.96 bitrate=4661.2kbits/s speed=0.763x
#
# frame= 5409 fps= 19 q=28.0 size=  122880KiB time=00:03:36.28 bitrate=4654.3kbits/s speed=0.763x
#
# frame= 5418 fps= 19 q=28.0 size=  123136KiB time=00:03:36.64 bitrate=4656.3kbits/s speed=0.763x
#
# frame= 5429 fps= 19 q=28.0 size=  123392KiB time=00:03:37.08 bitrate=4656.5kbits/s speed=0.763x
#
# frame= 5441 fps= 19 q=28.0 size=  123392KiB time=00:03:37.56 bitrate=4646.2kbits/s speed=0.763x
#
# frame= 5453 fps= 19 q=28.0 size=  123648KiB time=00:03:38.04 bitrate=4645.6kbits/s speed=0.763x
#
# frame= 5462 fps= 19 q=28.0 size=  123904KiB time=00:03:38.40 bitrate=4647.5kbits/s speed=0.763x
#
# frame= 5470 fps= 19 q=28.0 size=  124160KiB time=00:03:38.72 bitrate=4650.3kbits/s speed=0.763x
#
# frame= 5479 fps= 19 q=28.0 size=  124416KiB time=00:03:39.08 bitrate=4652.3kbits/s speed=0.763x
#
# frame= 5490 fps= 19 q=28.0 size=  124928KiB time=00:03:39.52 bitrate=4662.0kbits/s speed=0.763x
#
# frame= 5498 fps= 19 q=28.0 size=  124928KiB time=00:03:39.84 bitrate=4655.3kbits/s speed=0.763x
#
# frame= 5506 fps= 19 q=28.0 size=  125184KiB time=00:03:40.16 bitrate=4658.0kbits/s speed=0.762x
#
# frame= 5520 fps= 19 q=28.0 size=  125696KiB time=00:03:40.72 bitrate=4665.2kbits/s speed=0.763x
#
# frame= 5527 fps= 19 q=28.0 size=  125696KiB time=00:03:41.00 bitrate=4659.3kbits/s speed=0.762x
#
# frame= 5538 fps= 19 q=28.0 size=  125952KiB time=00:03:41.44 bitrate=4659.5kbits/s speed=0.763x
#
# frame= 5542 fps= 19 q=28.0 size=  125952KiB time=00:03:41.60 bitrate=4656.1kbits/s speed=0.762x
#
# frame= 5552 fps= 19 q=28.0 size=  126208KiB time=00:03:42.00 bitrate=4657.2kbits/s speed=0.762x
#
# frame= 5564 fps= 19 q=28.0 size=  126720KiB time=00:03:42.48 bitrate=4666.0kbits/s speed=0.762x
#
# frame= 5570 fps= 19 q=28.0 size=  126976KiB time=00:03:42.72 bitrate=4670.4kbits/s speed=0.761x
#
# frame= 5582 fps= 19 q=28.0 size=  127232KiB time=00:03:43.20 bitrate=4669.7kbits/s speed=0.762x
#
# frame= 5594 fps= 19 q=28.0 size=  127488KiB time=00:03:43.68 bitrate=4669.1kbits/s speed=0.762x
#
# frame= 5603 fps= 19 q=28.0 size=  127744KiB time=00:03:44.04 bitrate=4670.9kbits/s speed=0.762x
#
# frame= 5609 fps= 19 q=28.0 size=  127744KiB time=00:03:44.28 bitrate=4665.9kbits/s speed=0.761x
#
# frame= 5621 fps= 19 q=28.0 size=  128000KiB time=00:03:44.76 bitrate=4665.3kbits/s speed=0.762x
#
# frame= 5629 fps= 19 q=28.0 size=  128256KiB time=00:03:45.08 bitrate=4668.0kbits/s speed=0.761x
#
# frame= 5638 fps= 19 q=28.0 size=  128512KiB time=00:03:45.44 bitrate=4669.8kbits/s speed=0.761x
#
# frame= 5647 fps= 19 q=28.0 size=  128768KiB time=00:03:45.80 bitrate=4671.7kbits/s speed=0.761x
#
# frame= 5659 fps= 19 q=28.0 size=  129024KiB time=00:03:46.28 bitrate=4671.0kbits/s speed=0.761x
#
# frame= 5671 fps= 19 q=28.0 size=  129536KiB time=00:03:46.76 bitrate=4679.7kbits/s speed=0.762x
#
# frame= 5682 fps= 19 q=28.0 size=  129536KiB time=00:03:47.20 bitrate=4670.6kbits/s speed=0.762x
#
# frame= 5690 fps= 19 q=28.0 size=  129792KiB time=00:03:47.52 bitrate=4673.2kbits/s speed=0.762x
#
# frame= 5704 fps= 19 q=28.0 size=  130048KiB time=00:03:48.08 bitrate=4671.0kbits/s speed=0.762x
#
# frame= 5713 fps= 19 q=28.0 size=  130560KiB time=00:03:48.44 bitrate=4682.0kbits/s speed=0.762x
#
# frame= 5725 fps= 19 q=28.0 size=  130816KiB time=00:03:48.92 bitrate=4681.3kbits/s speed=0.762x
#
# frame= 5736 fps= 19 q=28.0 size=  131072KiB time=00:03:49.36 bitrate=4681.5kbits/s speed=0.762x
#
# frame= 5752 fps= 19 q=28.0 size=  131328KiB time=00:03:50.00 bitrate=4677.6kbits/s speed=0.763x
#
# frame= 5761 fps= 19 q=28.0 size=  131584KiB time=00:03:50.36 bitrate=4679.4kbits/s speed=0.763x
#
# frame= 5768 fps= 19 q=28.0 size=  131584KiB time=00:03:50.64 bitrate=4673.7kbits/s speed=0.763x
#
# frame= 5776 fps= 19 q=28.0 size=  131840KiB time=00:03:50.96 bitrate=4676.3kbits/s speed=0.762x
#
# frame= 5788 fps= 19 q=28.0 size=  132352KiB time=00:03:51.44 bitrate=4684.7kbits/s speed=0.763x
#
# frame= 5797 fps= 19 q=28.0 size=  132608KiB time=00:03:51.80 bitrate=4686.5kbits/s speed=0.763x
#
# frame= 5805 fps= 19 q=28.0 size=  132864KiB time=00:03:52.12 bitrate=4689.0kbits/s speed=0.762x
#
# frame= 5812 fps= 19 q=28.0 size=  132864KiB time=00:03:52.40 bitrate=4683.4kbits/s speed=0.762x
#
# frame= 5824 fps= 19 q=28.0 size=  133120KiB time=00:03:52.88 bitrate=4682.8kbits/s speed=0.762x
#
# frame= 5836 fps= 19 q=28.0 size=  133376KiB time=00:03:53.36 bitrate=4682.1kbits/s speed=0.762x
#
# frame= 5848 fps= 19 q=28.0 size=  133632KiB time=00:03:53.84 bitrate=4681.5kbits/s speed=0.763x
#
# frame= 5857 fps= 19 q=28.0 size=  133888KiB time=00:03:54.20 bitrate=4683.2kbits/s speed=0.763x
#
# frame= 5865 fps= 19 q=28.0 size=  134144KiB time=00:03:54.52 bitrate=4685.8kbits/s speed=0.762x
#
# frame= 5878 fps= 19 q=28.0 size=  134400KiB time=00:03:55.04 bitrate=4684.3kbits/s speed=0.763x
#
# frame= 5886 fps= 19 q=28.0 size=  134656KiB time=00:03:55.36 bitrate=4686.9kbits/s speed=0.762x
#
# frame= 5897 fps= 19 q=28.0 size=  134656KiB time=00:03:55.80 bitrate=4678.1kbits/s speed=0.762x
#
# frame= 5906 fps= 19 q=28.0 size=  134912KiB time=00:03:56.16 bitrate=4679.9kbits/s speed=0.762x
#
# frame= 5918 fps= 19 q=28.0 size=  135168KiB time=00:03:56.64 bitrate=4679.2kbits/s speed=0.763x
#
# frame= 5930 fps= 19 q=28.0 size=  135424KiB time=00:03:57.12 bitrate=4678.6kbits/s speed=0.763x
#
# frame= 5942 fps= 19 q=28.0 size=  135424KiB time=00:03:57.60 bitrate=4669.2kbits/s speed=0.763x
#
# frame= 5952 fps= 19 q=28.0 size=  135680KiB time=00:03:58.00 bitrate=4670.1kbits/s speed=0.763x
#
# frame= 5963 fps= 19 q=28.0 size=  136192KiB time=00:03:58.44 bitrate=4679.1kbits/s speed=0.763x
#
# frame= 5971 fps= 19 q=28.0 size=  136192KiB time=00:03:58.76 bitrate=4672.8kbits/s speed=0.763x
#
# frame= 5981 fps= 19 q=28.0 size=  136448KiB time=00:03:59.16 bitrate=4673.8kbits/s speed=0.763x
#
# frame= 5992 fps= 19 q=28.0 size=  136960KiB time=00:03:59.60 bitrate=4682.7kbits/s speed=0.763x
#
# frame= 6002 fps= 19 q=28.0 size=  137216KiB time=00:04:00.00 bitrate=4683.6kbits/s speed=0.763x
#
# frame= 6014 fps= 19 q=28.0 size=  137472KiB time=00:04:00.48 bitrate=4683.0kbits/s speed=0.763x
#
# frame= 6022 fps= 19 q=28.0 size=  137728KiB time=00:04:00.80 bitrate=4685.5kbits/s speed=0.763x
#
# frame= 6023 fps= 19 q=28.0 size=  137728KiB time=00:04:00.84 bitrate=4684.7kbits/s speed=0.762x
#
# frame= 6031 fps= 19 q=28.0 size=  137984KiB time=00:04:01.16 bitrate=4687.2kbits/s speed=0.762x
#
# frame= 6040 fps= 19 q=28.0 size=  138496KiB time=00:04:01.52 bitrate=4697.6kbits/s speed=0.762x
#
# frame= 6048 fps= 19 q=28.0 size=  138496KiB time=00:04:01.84 bitrate=4691.4kbits/s speed=0.761x
#
# frame= 6052 fps= 19 q=28.0 size=  138752KiB time=00:04:02.00 bitrate=4696.9kbits/s speed=0.761x
#
# frame= 6064 fps= 19 q=28.0 size=  139008KiB time=00:04:02.48 bitrate=4696.3kbits/s speed=0.761x
#
# frame= 6072 fps= 19 q=28.0 size=  139264KiB time=00:04:02.80 bitrate=4698.7kbits/s speed=0.761x
#
# frame= 6078 fps= 19 q=28.0 size=  139520KiB time=00:04:03.04 bitrate=4702.7kbits/s speed=0.76x
#
# frame= 6088 fps= 19 q=28.0 size=  139520KiB time=00:04:03.44 bitrate=4695.0kbits/s speed=0.76x
#
# frame= 6096 fps= 19 q=28.0 size=  139776KiB time=00:04:03.76 bitrate=4697.4kbits/s speed=0.76x
#
# frame= 6100 fps= 19 q=28.0 size=  139776KiB time=00:04:03.92 bitrate=4694.3kbits/s speed=0.759x
#
# frame= 6112 fps= 19 q=28.0 size=  140288KiB time=00:04:04.40 bitrate=4702.3kbits/s speed=0.759x
#
# frame= 6119 fps= 19 q=28.0 size=  140544KiB time=00:04:04.68 bitrate=4705.5kbits/s speed=0.759x
#
# frame= 6124 fps= 19 q=28.0 size=  140800KiB time=00:04:04.88 bitrate=4710.2kbits/s speed=0.759x
#
# frame= 6128 fps= 19 q=28.0 size=  140800KiB time=00:04:05.04 bitrate=4707.1kbits/s speed=0.758x
#
# frame= 6140 fps= 19 q=28.0 size=  141056KiB time=00:04:05.52 bitrate=4706.5kbits/s speed=0.758x
#
# frame= 6148 fps= 19 q=28.0 size=  141312KiB time=00:04:05.84 bitrate=4708.9kbits/s speed=0.758x
#
# frame= 6156 fps= 19 q=28.0 size=  141312KiB time=00:04:06.16 bitrate=4702.7kbits/s speed=0.758x
#
# frame= 6166 fps= 19 q=28.0 size=  141568KiB time=N/A bitrate=N/A speed=N/A
#
# frame= 6169 fps= 19 q=28.0 size=  141568KiB time=N/A bitrate=N/A speed=N/A
#
# frame= 6179 fps= 19 q=28.0 size=  141824KiB time=N/A bitrate=N/A speed=N/A
#
# frame= 6189 fps= 19 q=28.0 size=  142336KiB time=N/A bitrate=N/A speed=N/A
#
# frame= 6198 fps= 19 q=28.0 size=  142592KiB time=N/A bitrate=N/A speed=N/A
#
# frame= 6209 fps= 19 q=28.0 size=  142848KiB time=N/A bitrate=N/A speed=N/A
#
# frame= 6222 fps= 19 q=-1.0 size=  143104KiB time=N/A bitrate=N/A speed=N/A
#
# [out#0/mp4 @ 000002c957bffa40] video:139479KiB audio:3905KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.129578%
#
# frame= 6228 fps= 19 q=-1.0 Lsize=  143569KiB time=00:04:09.04 bitrate=4722.6kbits/s speed=0.758x
#
# [libx264 @ 000002c959ab8140] frame I:43    Avg QP:20.36  size:104449
#
# [libx264 @ 000002c959ab8140] frame P:1702  Avg QP:22.72  size: 45355
#
# [libx264 @ 000002c959ab8140] frame B:4483  Avg QP:24.96  size: 13638
#
# [libx264 @ 000002c959ab8140] consecutive B-frames:  3.6%  0.6%  1.5% 94.2%
#
# [libx264 @ 000002c959ab8140] mb I  I16..4: 27.7% 50.8% 21.6%
#
# [libx264 @ 000002c959ab8140] mb P  I16..4:  4.2%  8.6%  2.2%  P16..4: 48.8% 11.5%  8.7%  0.0%  0.0%    skip:15.9%
#
# [libx264 @ 000002c959ab8140] mb B  I16..4:  0.3%  0.5%  0.2%  B16..8: 46.2%  3.6%  0.7%  direct: 3.2%  skip:45.2%  L0:45.4% L1:50.8% BI: 3.8%
#
# [libx264 @ 000002c959ab8140] 8x8 transform intra:55.8% inter:73.2%
#
# [libx264 @ 000002c959ab8140] coded y,uvDC,uvAC intra: 63.8% 52.5% 5.3% inter: 16.1% 26.3% 0.3%
#
# [libx264 @ 000002c959ab8140] i16 v,h,dc,p: 22% 21% 22% 35%
#
# [libx264 @ 000002c959ab8140] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 19% 29%  5%  5%  5%  6%  5%  7%
#
# [libx264 @ 000002c959ab8140] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 22% 21%  5%  5%  5%  5%  5%  5%
#
# [libx264 @ 000002c959ab8140] i8c dc,h,v,p: 56% 19% 21%  4%
#
# [libx264 @ 000002c959ab8140] Weighted P-Frames: Y:6.8% UV:0.6%
#
# [libx264 @ 000002c959ab8140] ref P L0: 57.4% 10.9% 22.2%  9.1%  0.5%
#
# [libx264 @ 000002c959ab8140] ref B L0: 91.5%  7.0%  1.5%
#
# [libx264 @ 000002c959ab8140] ref B L1: 96.6%  3.4%
#
# [libx264 @ 000002c959ab8140] kb/s:4586.56
#
# [aac @ 000002c9598528c0] Qavg: 1055.677
#
# FFMPEG has finished processing.

# %%
# Switch the longest video's path with the new temporary one

all_paths[longest_video_index] = "./temporary.mp4"

# %%
# Find all delays
# Credit: Bucky und Stef

from prototype import *

delays = find_all_delays_with_pivot(all_paths, longest_video_index)

delays
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.2)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2avc1mp41', 'encoder': 'Lavf61.3.103'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1920, 1080], 'bitrate': 4586, 'fps': 25.0, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'handler_name': 'Ambarella AVC', 'encoder': 'Lavc61.5.103 libx264'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': 'eng', 'default': True, 'fps': 48000, 'bitrate': 128, 'metadata': {'handler_name': 'Ambarella AAC'}}], 'input_number': 0}], 'duration': 249.12, 'bitrate': 4721, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1920, 1080], 'video_bitrate': 4586, 'video_fps': 25.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 128, 'video_duration': 249.12, 'video_n_frames': 6228}
# c:\Users\enesy\AppData\Local\Programs\Python\Python311\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win64-v4.2.2.exe -i ./temporary.mp4 -loglevel error -f image2pipe -vf scale=1920:1080 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# Audio processing complete for temporary.
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'qt', 'minor_version': '0', 'compatible_brands': 'qt', 'creation_time': '2024-11-16T09:45:49.000000Z', 'com.apple.quicktime.location.accuracy.horizontal': '3.966881', 'com.apple.quicktime.full-frame-rate-playback-intent': '0', 'com.apple.quicktime.location.ISO6709': '+53.1684+008.6545+025.861/', 'com.apple.quicktime.make': 'Apple', 'com.apple.quicktime.model': 'iPhone 15 Pro', 'com.apple.quicktime.software': '18.0.1', 'com.apple.quicktime.creationdate': '2024-11-16T10:45:49+0100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1920, 1080], 'bitrate': 13098, 'fps': 59.96, 'codec_name': 'hevc', 'profile': '(Main 10)', 'metadata': {'creation_time': '2024-11-16T09:45:49.000000Z', 'handler_name': 'Core Media Video', 'encoder': 'HEVC'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 44100, 'bitrate': 179, 'metadata': {'creation_time': '2024-11-16T09:45:49.000000Z', 'handler_name': 'Core Media Audio'}}, {'input_number': 0, 'stream_number': 2, 'stream_type': 'data', 'language': None, 'default': True, 'metadata': {'creation_time': '2024-11-16T09:45:49.000000Z', 'handler_name': 'Core Media Metadata'}}, {'input_number': 0, 'stream_number': 3, 'stream_type': 'data', 'language': None, 'default': True, 'metadata': {'creation_time': '2024-11-16T09:45:49.000000Z', 'handler_name': 'Core Media Metadata'}}, {'input_number': 0, 'stream_number': 4, 'stream_type': 'data', 'language': None, 'default': True, 'metadata': {'creation_time': '2024-11-16T09:45:49.000000Z', 'handler_name': 'Core Media Metadata'}}, {'input_number': 0, 'stream_number': 5, 'stream_type': 'data', 'language': None, 'default': True, 'metadata': {'creation_time': '2024-11-16T09:45:49.000000Z', 'handler_name': 'Core Media Metadata'}}, {'input_number': 0, 'stream_number': 6, 'stream_type': 'data', 'language': None, 'default': True, 'metadata': {'creation_time': '2024-11-16T09:45:49.000000Z', 'handler_name': 'Core Media Metadata'}}], 'input_number': 0}], 'duration': 389.5, 'bitrate': 13460, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'hevc', 'video_profile': '(Main 10)', 'video_size': [1920, 1080], 'video_bitrate': 13098, 'video_fps': 59.96, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 44100, 'audio_bitrate': 179, 'default_data_input_number': 0, 'default_data_stream_number': 6, 'video_duration': 389.5, 'video_n_frames': 23354}
# c:\Users\enesy\AppData\Local\Programs\Python\Python311\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win64-v4.2.2.exe -i C:\Users\enesy\Videos\xd\2.MOV -loglevel error -f image2pipe -vf scale=1920:1080 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# Audio processing complete for 2.
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'avc1', 'minor_version': '0', 'compatible_brands': 'avc1isom', 'creation_time': '2024-11-16T09:45:51.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': 'eng', 'default': True, 'size': [1920, 1080], 'bitrate': 25680, 'fps': 29.97002997002997, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'creation_time': '2024-11-16T09:45:51.000000Z', 'handler_name': 'Ambarella AVC', 'encoder': 'Ambarella AVC encoder'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': 'eng', 'default': True, 'fps': 48000, 'bitrate': 192, 'metadata': {'creation_time': '2024-11-16T09:45:51.000000Z', 'handler_name': 'Ambarella AAC'}}], 'input_number': 0}], 'duration': 415.62, 'bitrate': 26261, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [1920, 1080], 'video_bitrate': 25680, 'video_fps': 29.97002997002997, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 192, 'video_duration': 415.62, 'video_n_frames': 12456}
# c:\Users\enesy\AppData\Local\Programs\Python\Python311\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win64-v4.2.2.exe -i C:\Users\enesy\Videos\xd\3.mp4 -loglevel error -f image2pipe -vf scale=1920:1080 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# Audio processing complete for 3.
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'mp42', 'minor_version': '1', 'compatible_brands': 'mp42avc1', 'creation_time': '2024-11-16T11:41:12.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1920, 1080], 'bitrate': 27013, 'fps': 59.94, 'codec_name': 'h264', 'profile': '(High)', 'metadata': {'creation_time': '2024-11-16T11:41:12.000000Z'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 125, 'metadata': {'creation_time': '2024-11-16T11:41:12.000000Z'}}], 'input_number': 0}], 'duration': 398.9, 'bitrate': 27149, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(High)', 'video_size': [1920, 1080], 'video_bitrate': 27013, 'video_fps': 59.94, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 125, 'video_duration': 398.9, 'video_n_frames': 23910}
# c:\Users\enesy\AppData\Local\Programs\Python\Python311\Lib\site-packages\imageio_ffmpeg\binaries\ffmpeg-win64-v4.2.2.exe -i C:\Users\enesy\Videos\xd\4.MP4 -loglevel error -f image2pipe -vf scale=1920:1080 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# Audio processing complete for 4.
# [0.0, -64.4649433106576, -82.91557823129251, -70.53260770975056]

# %%
# This is the edited commmand to include audio

import ffmpeg

OUTPUT_FILE_NAME_WITH_EXTENSION = "with_eeg_test.mp4"

# Load videos into ffmpeg
videos = [ffmpeg.input(path) for path in all_paths]

video_streams = [video.video for video in videos]

# Handling audio seperately
audio_streams = [video.audio for video in videos]

# We handle each video individually.
for index, video in enumerate(video_streams):

    # If the delay of the vide is negative:
    if delays[index] < 0:
        # We trim the video from the start
        video_streams[index] = ffmpeg.trim(video, start=round(abs(delays[index]), 2)).setpts("PTS-STARTPTS")
        
        # Update the corresponding video's duration
        durations[index] -= round(delays[index])

    else: # If the delay is positive
        # We delay/push the videos start by the amount
        video_streams[index] = ffmpeg.filter(video, "tpad", start_duration=round(delays[index], 2))

        audio_streams[index] = ffmpeg.filter(audio_streams[index], "apad", pad_dur=round(delays[index], 2))
        
# Put the videos on grid 2x2
xstacked = ffmpeg.filter(video_streams, "xstack", inputs="4", layout="0_0|0_h0|w0_0|w0_h0")

# Trying to split xstack

# We cut the whole video by the longest positive delay
# So that the videos begin at the same time.
video_start_adjusted = ffmpeg.trim(xstacked, start=max(delays)).setpts("PTS-STARTPTS")

# We take the audio stream with the maximum delay.
maximum_delay = np.argmax(delays)
audio_stream = audio_streams[maximum_delay]

# Cut the start of audio similarly
# This works because there will always be at least one 0 or larger delay.
# Thus no need to account for negatives.
audios_start_adjusted = ffmpeg.filter(audio_stream, "atrim", start=max(delays)).filter("asetpts", "PTS-STARTPTS")

# Scale down the video to 1080p 60FPS
# Normally, we are supposed to output 4K 60FPS
video_scaled = ffmpeg.filter(video_start_adjusted, "scale", 3840, 2160).filter('fps', fps=60, round='up')

# The output uses ultrafast preset for demonstration purposes.
# The video will continue until the shortest video ends, i.e set stop_duration = min(durations)
# If you want to test it out for a shorter time, change the "stop_duration" to amount of seconds you want (e.g 10 secs)
stop_duration = 10
out = ffmpeg.output(audio_stream, video_scaled, OUTPUT_FILE_NAME_WITH_EXTENSION, acodec="aac", vcodec="libx264", pix_fmt="yuv420p", crf=21, preset="superfast", progress="pipe:1", to=stop_duration)

# Compile command will return the terminal command to run FFMPEG as a string
command = out.compile()

print(" ".join(command))
# Out:
# ffmpeg -i ./temporary.mp4 -i C:\Users\enesy\Videos\xd\2.MOV -i C:\Users\enesy\Videos\xd\3.mp4 -i C:\Users\enesy\Videos\xd\4.MP4 -filter_complex [0:a]apad=pad_dur=0.0[s0];[0:v]tpad=start_duration=0.0[s1];[1:v]trim=start=64.46[s2];[s2]setpts=PTS-STARTPTS[s3];[2:v]trim=start=82.92[s4];[s4]setpts=PTS-STARTPTS[s5];[3:v]trim=start=70.53[s6];[s6]setpts=PTS-STARTPTS[s7];[s1][s3][s5][s7]xstack=inputs=4:layout=0_0|0_h0|w0_0|w0_h0[s8];[s8]trim=start=0.0[s9];[s9]setpts=PTS-STARTPTS[s10];[s10]scale=3840:2160[s11];[s11]fps=fps=60:round=up[s12] -map [s0] -map [s12] -acodec aac -crf 21 -pix_fmt yuv420p -preset superfast -progress pipe:1 -to 10 -vcodec libx264 with_eeg_test.mp4

# %%
# We are going to use pipes and subprocess
# This is because we want to see the progress of FFMPEG from our main process (i.e the notebook)

import subprocess
import datetime # For printing progress

# Run the FFMPEG subprocess
try:
    ffmpeg_process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, universal_newlines=True)
except OSError:
    print("OSError")
except ValueError:
    print("ValueError: Cannot run FFMPEG with given parameters.")

end_time = str(datetime.timedelta(seconds=stop_duration)) # Used for printing the last point of the video
# Print the progress that ffmpeg outputs
print("FFMPEG is starting, please wait a couple minutes.")
for line in ffmpeg_process.stdout:
    # for all output from ffmpeg
    print(line)

    # If you would like to print it in a simpler format
    # This shows how much of the video you processed
    # if line.startswith("out_time="):
    #     progress = line.split("=")[1]
    #     print(f"Progress: currently at {progress} / going until {end_time}", end="\r")
print("FFMPEG has finished processing.")

# IMPORTANT: you have to quit the FFMPEG process itself from Task Manager to stop it
# It will also not continue if the file exists already, make sure to delete the file if it looks like its doing nothing.
# Out:
# FFMPEG is starting, please wait a couple minutes.
# ffmpeg version 2024-05-08-git-e8e84dc325-full_build-www.gyan.dev Copyright (c) 2000-2024 the FFmpeg developers
#
#   built with gcc 13.2.0 (Rev5, Built by MSYS2 project)
#
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#
#   libavutil      59. 17.100 / 59. 17.100
#
#   libavcodec     61.  5.103 / 61.  5.103
#
#   libavformat    61.  3.103 / 61.  3.103
#
#   libavdevice    61.  2.100 / 61.  2.100
#
#   libavfilter    10.  2.101 / 10.  2.101
#
#   libswscale      8.  2.100 /  8.  2.100
#
#   libswresample   5.  2.100 /  5.  2.100
#
#   libpostproc    58.  2.100 / 58.  2.100
#
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './temporary.mp4':
#
#   Metadata:
#
#     major_brand     : isom
#
#     minor_version   : 512
#
#     compatible_brands: isomiso2avc1mp41
#
#     encoder         : Lavf61.3.103
#
#   Duration: 00:04:09.12, start: 0.000000, bitrate: 4721 kb/s
#
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuvj420p(pc, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 4586 kb/s, 25 fps, 25 tbr, 12800 tbn (default)
#
#       Metadata:
#
#         handler_name    :  Ambarella AVC
#
#         vendor_id       : [0][0][0][0]
#
#         encoder         : Lavc61.5.103 libx264
#
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#
#       Metadata:
#
#         handler_name    :  Ambarella AAC
#
#         vendor_id       : [0][0][0][0]
#
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'C:\Users\enesy\Videos\xd\2.MOV':
#
#   Metadata:
#
#     major_brand     : qt
#
#     minor_version   : 0
#
#     compatible_brands: qt
#
#     creation_time   : 2024-11-16T09:45:49.000000Z
#
#     com.apple.quicktime.location.accuracy.horizontal: 3.966881
#
#     com.apple.quicktime.full-frame-rate-playback-intent: 0
#
#     com.apple.quicktime.location.ISO6709: +53.1684+008.6545+025.861/
#
#     com.apple.quicktime.make: Apple
#
#     com.apple.quicktime.model: iPhone 15 Pro
#
#     com.apple.quicktime.software: 18.0.1
#
#     com.apple.quicktime.creationdate: 2024-11-16T10:45:49+0100
#
#   Duration: 00:06:29.50, start: 0.000000, bitrate: 13460 kb/s
#
#   Stream #1:0[0x1](und): Video: hevc (Main 10) (hvc1 / 0x31637668), yuv420p10le(tv, bt2020nc/bt2020/arib-std-b67), 1920x1080, 13098 kb/s, 59.96 fps, 59.94 tbr, 600 tbn (default)
#
#       Metadata:
#
#         creation_time   : 2024-11-16T09:45:49.000000Z
#
#         handler_name    : Core Media Video
#
#         vendor_id       : [0][0][0][0]
#
#         encoder         : HEVC
#
#       Side data:
#
#         DOVI configuration record: version: 1.0, profile: 8, level: 5, rpu flag: 1, el flag: 0, bl flag: 1, compatibility id: 4
#
#         Ambient Viewing Environment, ambient_illuminance=314.000000, ambient_light_x=0.312700, ambient_light_y=0.329000
#
#   Stream #1:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 179 kb/s (default)
#
#       Metadata:
#
#         creation_time   : 2024-11-16T09:45:49.000000Z
#
#         handler_name    : Core Media Audio
#
#         vendor_id       : [0][0][0][0]
#
#   Stream #1:2[0x3](und): Data: none (mebx / 0x7862656D) (default)
#
#       Metadata:
#
#         creation_time   : 2024-11-16T09:45:49.000000Z
#
#         handler_name    : Core Media Metadata
#
#   Stream #1:3[0x4](und): Data: none (mebx / 0x7862656D), 28 kb/s (default)
#
#       Metadata:
#
#         creation_time   : 2024-11-16T09:45:49.000000Z
#
#         handler_name    : Core Media Metadata
#
#   Stream #1:4[0x5](und): Data: none (mebx / 0x7862656D), 119 kb/s (default)
#
#       Metadata:
#
#         creation_time   : 2024-11-16T09:45:49.000000Z
#
#         handler_name    : Core Media Metadata
#
#   Stream #1:5[0x6](und): Data: none (mebx / 0x7862656D), 5 kb/s (default)
#
#       Metadata:
#
#         creation_time   : 2024-11-16T09:45:49.000000Z
#
#         handler_name    : Core Media Metadata
#
#   Stream #1:6[0x7](und): Data: none (mebx / 0x7862656D) (default)
#
#       Metadata:
#
#         creation_time   : 2024-11-16T09:45:49.000000Z
#
#         handler_name    : Core Media Metadata
#
# Input #2, mov,mp4,m4a,3gp,3g2,mj2, from 'C:\Users\enesy\Videos\xd\3.mp4':
#
#   Metadata:
#
#     major_brand     : avc1
#
#     minor_version   : 0
#
#     compatible_brands: avc1isom
#
#     creation_time   : 2024-11-16T09:45:51.000000Z
#
#   Duration: 00:06:55.62, start: 0.000000, bitrate: 26261 kb/s
#
#   Stream #2:0[0x1](eng): Video: h264 (Main) (avc1 / 0x31637661), yuvj420p(pc, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 25680 kb/s, 29.97 fps, 29.97 tbr, 30k tbn (default)
#
#       Metadata:
#
#         creation_time   : 2024-11-16T09:45:51.000000Z
#
#         handler_name    :  Ambarella AVC
#
#         vendor_id       : [0][0][0][0]
#
#         encoder         : Ambarella AVC encoder
#
#   Stream #2:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 192 kb/s (default)
#
#       Metadata:
#
#         creation_time   : 2024-11-16T09:45:51.000000Z
#
#         handler_name    :  Ambarella AAC
#
#         vendor_id       : [0][0][0][0]
#
# [mov,mp4,m4a,3gp,3g2,mj2 @ 000001654f2dcdc0] st: 0 edit list: 1 Missing key frame while searching for timestamp: 3003
#
# [mov,mp4,m4a,3gp,3g2,mj2 @ 000001654f2dcdc0] st: 0 edit list 1 Cannot find an index entry before timestamp: 3003.
#
# Input #3, mov,mp4,m4a,3gp,3g2,mj2, from 'C:\Users\enesy\Videos\xd\4.MP4':
#
#   Metadata:
#
#     major_brand     : mp42
#
#     minor_version   : 1
#
#     compatible_brands: mp42avc1
#
#     creation_time   : 2024-11-16T11:41:12.000000Z
#
#   Duration: 00:06:38.90, start: 0.000000, bitrate: 27149 kb/s
#
#   Stream #3:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1920x1080 [SAR 1:1 DAR 16:9], 27013 kb/s, 59.94 fps, 59.94 tbr, 180k tbn (default)
#
#       Metadata:
#
#         creation_time   : 2024-11-16T11:41:12.000000Z
#
#         vendor_id       : [0][0][0][0]
#
#   Stream #3:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 125 kb/s (default)
#
#       Metadata:
#
#         creation_time   : 2024-11-16T11:41:12.000000Z
#
#         vendor_id       : [0][0][0][0]
#
# Stream mapping:
#
#   Stream #0:0 (h264) -> tpad:default
#
#   Stream #0:1 (aac) -> apad:default
#
#   Stream #1:0 (hevc) -> trim:default
#
#   Stream #2:0 (h264) -> trim:default
#
#   Stream #3:0 (h264) -> trim:default
#
#   apad:default -> Stream #0:0 (aac)
#
#   fps:default -> Stream #0:1 (libx264)
#
# Press [q] to stop, [?] for help
#
# [swscaler @ 000001656c7d5ec0] deprecated pixel format used, make sure you did set range correctly
#
# [swscaler @ 000001656dea8dc0] deprecated pixel format used, make sure you did set range correctly
#
# [swscaler @ 000001656e14e000] deprecated pixel format used, make sure you did set range correctly
#
# [libx264 @ 000001654fbff6c0] using SAR=1/1
#
# [libx264 @ 000001654fbff6c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
#
# [libx264 @ 000001654fbff6c0] profile High, level 5.2, 4:2:0, 8-bit
#
# [libx264 @ 000001654fbff6c0] 264 - core 164 r3190 7ed753b - H.264/MPEG-4 AVC codec - Copyleft 2003-2024 - http://www.videolan.org/x264.html - options: cabac=1 ref=1 deblock=1:0:0 analyse=0x3:0x3 me=dia subme=1 psy=1 psy_rd=1.00:0.00 mixed_ref=0 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=0 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc=crf mbtree=0 crf=21.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 pb_ratio=1.30 aq=1:1.00
#
# Output #0, mp4, to 'with_eeg_test.mp4':
#
#   Metadata:
#
#     major_brand     : isom
#
#     minor_version   : 512
#
#     compatible_brands: isomiso2avc1mp41
#
#     encoder         : Lavf61.3.103
#
#   Stream #0:0: Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s
#
#       Metadata:
#
#         encoder         : Lavc61.5.103 aac
#
#   Stream #0:1: Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt2020nc/unknown/unknown, progressive), 3840x2160 [SAR 1:1 DAR 16:9], q=2-31, 60 fps, 15360 tbn
#
#       Metadata:
#
#         encoder         : Lavc61.5.103 libx264
#
#       Side data:
#
#         cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#
# frame=    0 fps=0.0 q=0.0 size=       0KiB time=N/A bitrate=N/A speed=N/A
#
# frame=0
#
# fps=0.00
#
# stream_0_1_q=0.0
#
# bitrate=N/A
#
# total_size=48
#
# out_time_us=N/A
#
# out_time_ms=N/A
#
# out_time=N/A
#
# dup_frames=0
#
# drop_frames=0
#
# speed=N/A
#
# progress=continue
#
# frame=    0 fps=0.0 q=0.0 size=       0KiB time=N/A bitrate=N/A speed=N/A
#
# frame=0
#
# fps=0.00
#
# stream_0_1_q=0.0
#
# bitrate=N/A
#
# total_size=48
#
# out_time_us=N/A
#
# out_time_ms=N/A
#
# out_time=N/A
#
# dup_frames=0
#
# drop_frames=0
#
# speed=N/A
#
# progress=continue
#
# frame=    0 fps=0.0 q=0.0 size=       0KiB time=N/A bitrate=N/A speed=N/A
#
# frame=0
#
# fps=0.00
#
# stream_0_1_q=0.0
#
# bitrate=N/A
#
# total_size=48
#
# out_time_us=N/A
#
# out_time_ms=N/A
#
# out_time=N/A
#
# dup_frames=0
#
# drop_frames=0
#
# speed=N/A
#
# progress=continue
#
# frame=    0 fps=0.0 q=0.0 size=       0KiB time=N/A bitrate=N/A speed=N/A
#
# frame=0
#
# fps=0.00
#
# stream_0_1_q=0.0
#
# bitrate=N/A
#
# total_size=48
#
# out_time_us=N/A
#
# out_time_ms=N/A
#
# out_time=N/A
#
# dup_frames=0
#
# drop_frames=0
#
# speed=N/A
#
# progress=continue
#
# frame=    4 fps=0.1 q=25.0 size=     768KiB time=00:00:00.03 bitrate=188757.1kbits/s speed=0.000686x
#
# frame=4
#
# fps=0.08
#
# stream_0_1_q=25.0
#
# bitrate=188757.1kbits/s
#
# total_size=786480
#
# out_time_us=33333
#
# out_time_ms=33333
#
# out_time=00:00:00.033333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.000686x
#
# progress=continue
#
# frame=    9 fps=0.2 q=26.0 size=    1024KiB time=00:00:00.11 bitrate=71905.4kbits/s speed=0.00238x
#
# frame=9
#
# fps=0.18
#
# stream_0_1_q=26.0
#
# bitrate=71905.4kbits/s
#
# total_size=1048624
#
# out_time_us=116667
#
# out_time_ms=116667
#
# out_time=00:00:00.116667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.00238x
#
# progress=continue
#
# frame=   14 fps=0.3 q=26.0 size=    1280KiB time=00:00:00.20 bitrate=52430.7kbits/s speed=0.00403x
#
# frame=14
#
# fps=0.28
#
# stream_0_1_q=26.0
#
# bitrate=52430.7kbits/s
#
# total_size=1310768
#
# out_time_us=200000
#
# out_time_ms=200000
#
# out_time=00:00:00.200000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.00403x
#
# progress=continue
#
# frame=   19 fps=0.4 q=23.0 size=    1792KiB time=00:00:00.28 bitrate=51813.4kbits/s speed=0.00565x
#
# frame=19
#
# fps=0.38
#
# stream_0_1_q=23.0
#
# bitrate=51813.4kbits/s
#
# total_size=1835056
#
# out_time_us=283333
#
# out_time_ms=283333
#
# out_time=00:00:00.283333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.00565x
#
# progress=continue
#
# frame=   24 fps=0.5 q=24.0 size=    2048KiB time=00:00:00.36 bitrate=45757.0kbits/s speed=0.00724x
#
# frame=24
#
# fps=0.47
#
# stream_0_1_q=24.0
#
# bitrate=45757.0kbits/s
#
# total_size=2097200
#
# out_time_us=366667
#
# out_time_ms=366667
#
# out_time=00:00:00.366667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.00724x
#
# progress=continue
#
# frame=   28 fps=0.5 q=24.0 size=    2304KiB time=00:00:00.43 bitrate=43557.2kbits/s speed=0.00847x
#
# frame=28
#
# fps=0.55
#
# stream_0_1_q=24.0
#
# bitrate=43557.2kbits/s
#
# total_size=2359344
#
# out_time_us=433333
#
# out_time_ms=433333
#
# out_time=00:00:00.433333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.00847x
#
# progress=continue
#
# frame=   32 fps=0.6 q=24.0 size=    2560KiB time=00:00:00.50 bitrate=41943.8kbits/s speed=0.00967x
#
# frame=32
#
# fps=0.62
#
# stream_0_1_q=24.0
#
# bitrate=41943.8kbits/s
#
# total_size=2621488
#
# out_time_us=500000
#
# out_time_ms=500000
#
# out_time=00:00:00.500000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.00967x
#
# progress=continue
#
# frame=   37 fps=0.7 q=26.0 size=    3072KiB time=00:00:00.58 bitrate=43142.1kbits/s speed=0.0112x
#
# frame=37
#
# fps=0.71
#
# stream_0_1_q=26.0
#
# bitrate=43142.1kbits/s
#
# total_size=3145776
#
# out_time_us=583333
#
# out_time_ms=583333
#
# out_time=00:00:00.583333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0112x
#
# progress=continue
#
# frame=   43 fps=0.8 q=24.0 size=    3328KiB time=00:00:00.68 bitrate=39897.6kbits/s speed=0.013x
#
# frame=43
#
# fps=0.82
#
# stream_0_1_q=24.0
#
# bitrate=39897.6kbits/s
#
# total_size=3407920
#
# out_time_us=683333
#
# out_time_ms=683333
#
# out_time=00:00:00.683333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.013x
#
# progress=continue
#
# frame=   47 fps=0.9 q=24.0 size=    3840KiB time=00:00:00.75 bitrate=41943.6kbits/s speed=0.0141x
#
# frame=47
#
# fps=0.88
#
# stream_0_1_q=24.0
#
# bitrate=41943.6kbits/s
#
# total_size=3932208
#
# out_time_us=750000
#
# out_time_ms=750000
#
# out_time=00:00:00.750000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0141x
#
# progress=continue
#
# frame=   52 fps=1.0 q=25.0 size=    4096KiB time=00:00:00.83 bitrate=40265.8kbits/s speed=0.0155x
#
# frame=52
#
# fps=0.97
#
# stream_0_1_q=25.0
#
# bitrate=40265.8kbits/s
#
# total_size=4194352
#
# out_time_us=833333
#
# out_time_ms=833333
#
# out_time=00:00:00.833333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0155x
#
# progress=continue
#
# frame=   57 fps=1.0 q=26.0 size=    4352KiB time=00:00:00.91 bitrate=38893.0kbits/s speed=0.0169x
#
# frame=57
#
# fps=1.05
#
# stream_0_1_q=26.0
#
# bitrate=38893.0kbits/s
#
# total_size=4456496
#
# out_time_us=916667
#
# out_time_ms=916667
#
# out_time=00:00:00.916667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0169x
#
# progress=continue
#
# frame=   61 fps=1.1 q=26.0 size=    4608KiB time=00:00:00.98 bitrate=38388.9kbits/s speed=0.0179x
#
# frame=61
#
# fps=1.11
#
# stream_0_1_q=26.0
#
# bitrate=38388.9kbits/s
#
# total_size=4718640
#
# out_time_us=983333
#
# out_time_ms=983333
#
# out_time=00:00:00.983333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0179x
#
# progress=continue
#
# frame=   66 fps=1.2 q=26.0 size=    4864KiB time=00:00:01.06 bitrate=37355.9kbits/s speed=0.0193x
#
# frame=66
#
# fps=1.19
#
# stream_0_1_q=26.0
#
# bitrate=37355.9kbits/s
#
# total_size=4980784
#
# out_time_us=1066667
#
# out_time_ms=1066667
#
# out_time=00:00:01.066667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0193x
#
# progress=continue
#
# frame=   71 fps=1.3 q=23.0 size=    5376KiB time=00:00:01.15 bitrate=38296.2kbits/s speed=0.0206x
#
# frame=71
#
# fps=1.27
#
# stream_0_1_q=23.0
#
# bitrate=38296.2kbits/s
#
# total_size=5505072
#
# out_time_us=1150000
#
# out_time_ms=1150000
#
# out_time=00:00:01.150000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0206x
#
# progress=continue
#
# frame=   76 fps=1.3 q=24.0 size=    5888KiB time=00:00:01.23 bitrate=39109.4kbits/s speed=0.0219x
#
# frame=76
#
# fps=1.35
#
# stream_0_1_q=24.0
#
# bitrate=39109.4kbits/s
#
# total_size=6029360
#
# out_time_us=1233333
#
# out_time_ms=1233333
#
# out_time=00:00:01.233333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0219x
#
# progress=continue
#
# frame=   80 fps=1.4 q=24.0 size=    6144KiB time=00:00:01.30 bitrate=38716.9kbits/s speed=0.0228x
#
# frame=80
#
# fps=1.41
#
# stream_0_1_q=24.0
#
# bitrate=38716.9kbits/s
#
# total_size=6291504
#
# out_time_us=1300000
#
# out_time_ms=1300000
#
# out_time=00:00:01.300000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0228x
#
# progress=continue
#
# frame=   85 fps=1.5 q=26.0 size=    6400KiB time=00:00:01.38 bitrate=37900.6kbits/s speed=0.0241x
#
# frame=85
#
# fps=1.48
#
# stream_0_1_q=26.0
#
# bitrate=37900.6kbits/s
#
# total_size=6553648
#
# out_time_us=1383333
#
# out_time_ms=1383333
#
# out_time=00:00:01.383333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0241x
#
# progress=continue
#
# frame=   90 fps=1.6 q=26.0 size=    6912KiB time=00:00:01.46 bitrate=38606.9kbits/s speed=0.0253x
#
# frame=90
#
# fps=1.55
#
# stream_0_1_q=26.0
#
# bitrate=38606.9kbits/s
#
# total_size=7077936
#
# out_time_us=1466667
#
# out_time_ms=1466667
#
# out_time=00:00:01.466667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0253x
#
# progress=continue
#
# frame=   95 fps=1.6 q=23.0 size=    7168KiB time=00:00:01.55 bitrate=37884.3kbits/s speed=0.0265x
#
# frame=95
#
# fps=1.62
#
# stream_0_1_q=23.0
#
# bitrate=37884.3kbits/s
#
# total_size=7340080
#
# out_time_us=1550000
#
# out_time_ms=1550000
#
# out_time=00:00:01.550000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0265x
#
# progress=continue
#
# frame=  100 fps=1.7 q=24.0 size=    7424KiB time=00:00:01.63 bitrate=37235.4kbits/s speed=0.0277x
#
# frame=100
#
# fps=1.69
#
# stream_0_1_q=24.0
#
# bitrate=37235.4kbits/s
#
# total_size=7602224
#
# out_time_us=1633333
#
# out_time_ms=1633333
#
# out_time=00:00:01.633333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0277x
#
# progress=continue
#
# frame=  104 fps=1.7 q=24.0 size=    7680KiB time=00:00:01.70 bitrate=37008.8kbits/s speed=0.0286x
#
# frame=104
#
# fps=1.75
#
# stream_0_1_q=24.0
#
# bitrate=37008.8kbits/s
#
# total_size=7864368
#
# out_time_us=1700000
#
# out_time_ms=1700000
#
# out_time=00:00:01.700000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0286x
#
# progress=continue
#
# frame=  109 fps=1.8 q=25.0 size=    7936KiB time=00:00:01.78 bitrate=36455.4kbits/s speed=0.0297x
#
# frame=109
#
# fps=1.82
#
# stream_0_1_q=25.0
#
# bitrate=36455.4kbits/s
#
# total_size=8126512
#
# out_time_us=1783333
#
# out_time_ms=1783333
#
# out_time=00:00:01.783333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0297x
#
# progress=continue
#
# frame=  115 fps=1.9 q=23.0 size=    8448KiB time=00:00:01.88 bitrate=36746.8kbits/s speed=0.0311x
#
# frame=115
#
# fps=1.90
#
# stream_0_1_q=23.0
#
# bitrate=36746.8kbits/s
#
# total_size=8650800
#
# out_time_us=1883333
#
# out_time_ms=1883333
#
# out_time=00:00:01.883333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0311x
#
# progress=continue
#
# frame=  120 fps=2.0 q=24.0 size=    8704KiB time=00:00:01.96 bitrate=36256.0kbits/s speed=0.0322x
#
# frame=120
#
# fps=1.96
#
# stream_0_1_q=24.0
#
# bitrate=36256.0kbits/s
#
# total_size=8912944
#
# out_time_us=1966667
#
# out_time_ms=1966667
#
# out_time=00:00:01.966667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0322x
#
# progress=continue
#
# frame=  123 fps=2.0 q=23.0 size=    8960KiB time=00:00:02.01 bitrate=36397.0kbits/s speed=0.0327x
#
# frame=123
#
# fps=2.00
#
# stream_0_1_q=23.0
#
# bitrate=36397.0kbits/s
#
# total_size=9175088
#
# out_time_us=2016667
#
# out_time_ms=2016667
#
# out_time=00:00:02.016667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0327x
#
# progress=continue
#
# frame=  128 fps=2.1 q=24.0 size=    9216KiB time=00:00:02.10 bitrate=35951.4kbits/s speed=0.0338x
#
# frame=128
#
# fps=2.06
#
# stream_0_1_q=24.0
#
# bitrate=35951.4kbits/s
#
# total_size=9437232
#
# out_time_us=2100000
#
# out_time_ms=2100000
#
# out_time=00:00:02.100000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0338x
#
# progress=continue
#
# frame=  133 fps=2.1 q=25.0 size=    9728KiB time=00:00:02.18 bitrate=36500.2kbits/s speed=0.0349x
#
# frame=133
#
# fps=2.12
#
# stream_0_1_q=25.0
#
# bitrate=36500.2kbits/s
#
# total_size=9961520
#
# out_time_us=2183333
#
# out_time_ms=2183333
#
# out_time=00:00:02.183333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0349x
#
# progress=continue
#
# frame=  138 fps=2.2 q=25.0 size=    9728KiB time=00:00:02.26 bitrate=35158.3kbits/s speed=0.0359x
#
# frame=138
#
# fps=2.19
#
# stream_0_1_q=25.0
#
# bitrate=35158.3kbits/s
#
# total_size=9961520
#
# out_time_us=2266667
#
# out_time_ms=2266667
#
# out_time=00:00:02.266667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0359x
#
# progress=continue
#
# frame=  143 fps=2.2 q=23.0 size=   10240KiB time=00:00:02.35 bitrate=35696.4kbits/s speed=0.0369x
#
# frame=143
#
# fps=2.25
#
# stream_0_1_q=23.0
#
# bitrate=35696.4kbits/s
#
# total_size=10485808
#
# out_time_us=2350000
#
# out_time_ms=2350000
#
# out_time=00:00:02.350000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0369x
#
# progress=continue
#
# frame=  148 fps=2.3 q=24.0 size=   10496KiB time=00:00:02.43 bitrate=35335.7kbits/s speed=0.0379x
#
# frame=148
#
# fps=2.30
#
# stream_0_1_q=24.0
#
# bitrate=35335.7kbits/s
#
# total_size=10747952
#
# out_time_us=2433333
#
# out_time_ms=2433333
#
# out_time=00:00:02.433333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0379x
#
# progress=continue
#
# frame=  152 fps=2.3 q=24.0 size=   10752KiB time=00:00:02.50 bitrate=35232.3kbits/s speed=0.0386x
#
# frame=152
#
# fps=2.35
#
# stream_0_1_q=24.0
#
# bitrate=35232.3kbits/s
#
# total_size=11010096
#
# out_time_us=2500000
#
# out_time_ms=2500000
#
# out_time=00:00:02.500000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0386x
#
# progress=continue
#
# frame=  157 fps=2.4 q=25.0 size=   11008KiB time=00:00:02.58 bitrate=34907.6kbits/s speed=0.0396x
#
# frame=157
#
# fps=2.41
#
# stream_0_1_q=25.0
#
# bitrate=34907.6kbits/s
#
# total_size=11272240
#
# out_time_us=2583333
#
# out_time_ms=2583333
#
# out_time=00:00:02.583333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0396x
#
# progress=continue
#
# frame=  162 fps=2.5 q=25.0 size=   11264KiB time=00:00:02.66 bitrate=34603.1kbits/s speed=0.0405x
#
# frame=162
#
# fps=2.46
#
# stream_0_1_q=25.0
#
# bitrate=34603.1kbits/s
#
# total_size=11534384
#
# out_time_us=2666667
#
# out_time_ms=2666667
#
# out_time=00:00:02.666667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0405x
#
# progress=continue
#
# frame=  168 fps=2.5 q=24.0 size=   11776KiB time=00:00:02.76 bitrate=34868.4kbits/s speed=0.0417x
#
# frame=168
#
# fps=2.53
#
# stream_0_1_q=24.0
#
# bitrate=34868.4kbits/s
#
# total_size=12058672
#
# out_time_us=2766667
#
# out_time_ms=2766667
#
# out_time=00:00:02.766667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0417x
#
# progress=continue
#
# frame=  172 fps=2.6 q=24.0 size=   12032KiB time=00:00:02.83 bitrate=34788.2kbits/s speed=0.0424x
#
# frame=172
#
# fps=2.57
#
# stream_0_1_q=24.0
#
# bitrate=34788.2kbits/s
#
# total_size=12320816
#
# out_time_us=2833333
#
# out_time_ms=2833333
#
# out_time=00:00:02.833333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0424x
#
# progress=continue
#
# frame=  176 fps=2.6 q=24.0 size=   12544KiB time=00:00:02.90 bitrate=35434.8kbits/s speed=0.043x
#
# frame=176
#
# fps=2.61
#
# stream_0_1_q=24.0
#
# bitrate=35434.8kbits/s
#
# total_size=12845104
#
# out_time_us=2900000
#
# out_time_ms=2900000
#
# out_time=00:00:02.900000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.043x
#
# progress=continue
#
# frame=  181 fps=2.7 q=26.0 size=   12800KiB time=00:00:02.98 bitrate=35147.9kbits/s speed=0.0439x
#
# frame=181
#
# fps=2.67
#
# stream_0_1_q=26.0
#
# bitrate=35147.9kbits/s
#
# total_size=13107248
#
# out_time_us=2983333
#
# out_time_ms=2983333
#
# out_time=00:00:02.983333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0439x
#
# progress=continue
#
# frame=  186 fps=2.7 q=26.0 size=   13056KiB time=00:00:03.06 bitrate=34876.7kbits/s speed=0.0448x
#
# frame=186
#
# fps=2.72
#
# stream_0_1_q=26.0
#
# bitrate=34876.7kbits/s
#
# total_size=13369392
#
# out_time_us=3066667
#
# out_time_ms=3066667
#
# out_time=00:00:03.066667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0448x
#
# progress=continue
#
# frame=  191 fps=2.8 q=23.0 size=   13568KiB time=00:00:03.15 bitrate=35285.5kbits/s speed=0.0457x
#
# frame=191
#
# fps=2.77
#
# stream_0_1_q=23.0
#
# bitrate=35285.5kbits/s
#
# total_size=13893680
#
# out_time_us=3150000
#
# out_time_ms=3150000
#
# out_time=00:00:03.150000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0457x
#
# progress=continue
#
# frame=  195 fps=2.8 q=23.0 size=   13824KiB time=00:00:03.21 bitrate=35206.2kbits/s speed=0.0463x
#
# frame=195
#
# fps=2.81
#
# stream_0_1_q=23.0
#
# bitrate=35206.2kbits/s
#
# total_size=14155824
#
# out_time_us=3216667
#
# out_time_ms=3216667
#
# out_time=00:00:03.216667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0463x
#
# progress=continue
#
# frame=  200 fps=2.9 q=24.0 size=   14080KiB time=00:00:03.30 bitrate=34952.6kbits/s speed=0.0472x
#
# frame=200
#
# fps=2.86
#
# stream_0_1_q=24.0
#
# bitrate=34952.6kbits/s
#
# total_size=14417968
#
# out_time_us=3300000
#
# out_time_ms=3300000
#
# out_time=00:00:03.300000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0472x
#
# progress=continue
#
# frame=  204 fps=2.9 q=24.0 size=   14336KiB time=00:00:03.36 bitrate=34883.4kbits/s speed=0.0478x
#
# frame=204
#
# fps=2.89
#
# stream_0_1_q=24.0
#
# bitrate=34883.4kbits/s
#
# total_size=14680112
#
# out_time_us=3366667
#
# out_time_ms=3366667
#
# out_time=00:00:03.366667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0478x
#
# progress=continue
#
# frame=  208 fps=2.9 q=24.0 size=   14592KiB time=00:00:03.43 bitrate=34816.9kbits/s speed=0.0483x
#
# frame=208
#
# fps=2.93
#
# stream_0_1_q=24.0
#
# bitrate=34816.9kbits/s
#
# total_size=14942256
#
# out_time_us=3433333
#
# out_time_ms=3433333
#
# out_time=00:00:03.433333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0483x
#
# progress=continue
#
# frame=  212 fps=3.0 q=24.0 size=   14848KiB time=00:00:03.50 bitrate=34752.9kbits/s speed=0.0489x
#
# frame=212
#
# fps=2.96
#
# stream_0_1_q=24.0
#
# bitrate=34752.9kbits/s
#
# total_size=15204400
#
# out_time_us=3500000
#
# out_time_ms=3500000
#
# out_time=00:00:03.500000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0489x
#
# progress=continue
#
# frame=  216 fps=3.0 q=24.0 size=   15360KiB time=00:00:03.56 bitrate=35279.3kbits/s speed=0.0495x
#
# frame=216
#
# fps=3.00
#
# stream_0_1_q=24.0
#
# bitrate=35279.3kbits/s
#
# total_size=15728688
#
# out_time_us=3566667
#
# out_time_ms=3566667
#
# out_time=00:00:03.566667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0495x
#
# progress=continue
#
# frame=  220 fps=3.0 q=24.0 size=   15616KiB time=00:00:03.63 bitrate=35209.2kbits/s speed=0.05x
#
# frame=220
#
# fps=3.03
#
# stream_0_1_q=24.0
#
# bitrate=35209.2kbits/s
#
# total_size=15990832
#
# out_time_us=3633333
#
# out_time_ms=3633333
#
# out_time=00:00:03.633333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.05x
#
# progress=continue
#
# frame=  224 fps=3.1 q=24.0 size=   15872KiB time=00:00:03.70 bitrate=35141.6kbits/s speed=0.0506x
#
# frame=224
#
# fps=3.06
#
# stream_0_1_q=24.0
#
# bitrate=35141.6kbits/s
#
# total_size=16252976
#
# out_time_us=3700000
#
# out_time_ms=3700000
#
# out_time=00:00:03.700000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0506x
#
# progress=continue
#
# frame=  229 fps=3.1 q=26.0 size=   16128KiB time=00:00:03.78 bitrate=34921.8kbits/s speed=0.0513x
#
# frame=229
#
# fps=3.11
#
# stream_0_1_q=26.0
#
# bitrate=34921.8kbits/s
#
# total_size=16515120
#
# out_time_us=3783333
#
# out_time_ms=3783333
#
# out_time=00:00:03.783333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0513x
#
# progress=continue
#
# frame=  233 fps=3.1 q=26.0 size=   16384KiB time=00:00:03.85 bitrate=34861.8kbits/s speed=0.0519x
#
# frame=233
#
# fps=3.14
#
# stream_0_1_q=26.0
#
# bitrate=34861.8kbits/s
#
# total_size=16777264
#
# out_time_us=3850000
#
# out_time_ms=3850000
#
# out_time=00:00:03.850000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0519x
#
# progress=continue
#
# frame=  238 fps=3.2 q=26.0 size=   16640KiB time=00:00:03.93 bitrate=34656.4kbits/s speed=0.0526x
#
# frame=238
#
# fps=3.18
#
# stream_0_1_q=26.0
#
# bitrate=34656.4kbits/s
#
# total_size=17039408
#
# out_time_us=3933333
#
# out_time_ms=3933333
#
# out_time=00:00:03.933333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0526x
#
# progress=continue
#
# frame=  243 fps=3.2 q=26.0 size=   17152KiB time=00:00:04.01 bitrate=34981.6kbits/s speed=0.0534x
#
# frame=243
#
# fps=3.23
#
# stream_0_1_q=26.0
#
# bitrate=34981.6kbits/s
#
# total_size=17563696
#
# out_time_us=4016667
#
# out_time_ms=4016667
#
# out_time=00:00:04.016667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0534x
#
# progress=continue
#
# frame=  248 fps=3.3 q=26.0 size=   17408KiB time=00:00:04.10 bitrate=34782.1kbits/s speed=0.0541x
#
# frame=248
#
# fps=3.27
#
# stream_0_1_q=26.0
#
# bitrate=34782.1kbits/s
#
# total_size=17825840
#
# out_time_us=4100000
#
# out_time_ms=4100000
#
# out_time=00:00:04.100000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0541x
#
# progress=continue
#
# frame=  252 fps=3.3 q=26.0 size=   18176KiB time=00:00:04.16 bitrate=35735.6kbits/s speed=0.0546x
#
# frame=252
#
# fps=3.30
#
# stream_0_1_q=26.0
#
# bitrate=35735.6kbits/s
#
# total_size=18612272
#
# out_time_us=4166667
#
# out_time_ms=4166667
#
# out_time=00:00:04.166667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0546x
#
# progress=continue
#
# frame=  256 fps=3.3 q=26.0 size=   18432KiB time=00:00:04.23 bitrate=35668.2kbits/s speed=0.0551x
#
# frame=256
#
# fps=3.33
#
# stream_0_1_q=26.0
#
# bitrate=35668.2kbits/s
#
# total_size=18874416
#
# out_time_us=4233333
#
# out_time_ms=4233333
#
# out_time=00:00:04.233333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0551x
#
# progress=continue
#
# frame=  261 fps=3.4 q=23.0 size=   18944KiB time=00:00:04.31 bitrate=35951.3kbits/s speed=0.0558x
#
# frame=261
#
# fps=3.37
#
# stream_0_1_q=23.0
#
# bitrate=35951.3kbits/s
#
# total_size=19398704
#
# out_time_us=4316667
#
# out_time_ms=4316667
#
# out_time=00:00:04.316667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0558x
#
# progress=continue
#
# frame=  266 fps=3.4 q=24.0 size=   19200KiB time=00:00:04.40 bitrate=35747.0kbits/s speed=0.0565x
#
# frame=266
#
# fps=3.42
#
# stream_0_1_q=24.0
#
# bitrate=35747.0kbits/s
#
# total_size=19660848
#
# out_time_us=4400000
#
# out_time_ms=4400000
#
# out_time=00:00:04.400000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0565x
#
# progress=continue
#
# frame=  271 fps=3.5 q=26.0 size=   19456KiB time=00:00:04.48 bitrate=35550.3kbits/s speed=0.0572x
#
# frame=271
#
# fps=3.46
#
# stream_0_1_q=26.0
#
# bitrate=35550.3kbits/s
#
# total_size=19922992
#
# out_time_us=4483333
#
# out_time_ms=4483333
#
# out_time=00:00:04.483333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0572x
#
# progress=continue
#
# frame=  275 fps=3.5 q=26.0 size=   19712KiB time=00:00:04.55 bitrate=35490.3kbits/s speed=0.0576x
#
# frame=275
#
# fps=3.48
#
# stream_0_1_q=26.0
#
# bitrate=35490.3kbits/s
#
# total_size=20185136
#
# out_time_us=4550000
#
# out_time_ms=4550000
#
# out_time=00:00:04.550000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0576x
#
# progress=continue
#
# frame=  281 fps=3.5 q=23.0 size=   20224KiB time=00:00:04.65 bitrate=35629.1kbits/s speed=0.0585x
#
# frame=281
#
# fps=3.54
#
# stream_0_1_q=23.0
#
# bitrate=35629.1kbits/s
#
# total_size=20709424
#
# out_time_us=4650000
#
# out_time_ms=4650000
#
# out_time=00:00:04.650000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0585x
#
# progress=continue
#
# frame=  285 fps=3.6 q=23.0 size=   20480KiB time=00:00:04.71 bitrate=35570.1kbits/s speed=0.059x
#
# frame=285
#
# fps=3.56
#
# stream_0_1_q=23.0
#
# bitrate=35570.1kbits/s
#
# total_size=20971568
#
# out_time_us=4716667
#
# out_time_ms=4716667
#
# out_time=00:00:04.716667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.059x
#
# progress=continue
#
# frame=  289 fps=3.6 q=23.0 size=   20736KiB time=00:00:04.78 bitrate=35512.8kbits/s speed=0.0594x
#
# frame=289
#
# fps=3.59
#
# stream_0_1_q=23.0
#
# bitrate=35512.8kbits/s
#
# total_size=21233712
#
# out_time_us=4783333
#
# out_time_ms=4783333
#
# out_time=00:00:04.783333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0594x
#
# progress=continue
#
# frame=  295 fps=3.6 q=25.0 size=   21248KiB time=00:00:04.88 bitrate=35644.5kbits/s speed=0.0602x
#
# frame=295
#
# fps=3.64
#
# stream_0_1_q=25.0
#
# bitrate=35644.5kbits/s
#
# total_size=21758000
#
# out_time_us=4883333
#
# out_time_ms=4883333
#
# out_time=00:00:04.883333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0602x
#
# progress=continue
#
# frame=  299 fps=3.7 q=25.0 size=   21504KiB time=00:00:04.95 bitrate=35588.1kbits/s speed=0.0607x
#
# frame=299
#
# fps=3.67
#
# stream_0_1_q=25.0
#
# bitrate=35588.1kbits/s
#
# total_size=22020144
#
# out_time_us=4950000
#
# out_time_ms=4950000
#
# out_time=00:00:04.950000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0607x
#
# progress=continue
#
# frame=  304 fps=3.7 q=25.0 size=   21760KiB time=00:00:05.03 bitrate=35415.6kbits/s speed=0.0613x
#
# frame=304
#
# fps=3.70
#
# stream_0_1_q=25.0
#
# bitrate=35415.6kbits/s
#
# total_size=22282288
#
# out_time_us=5033333
#
# out_time_ms=5033333
#
# out_time=00:00:05.033333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0613x
#
# progress=continue
#
# frame=  309 fps=3.7 q=23.0 size=   22016KiB time=00:00:05.11 bitrate=35248.6kbits/s speed=0.0619x
#
# frame=309
#
# fps=3.74
#
# stream_0_1_q=23.0
#
# bitrate=35248.6kbits/s
#
# total_size=22544432
#
# out_time_us=5116667
#
# out_time_ms=5116667
#
# out_time=00:00:05.116667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0619x
#
# progress=continue
#
# frame=  314 fps=3.8 q=24.0 size=   22528KiB time=00:00:05.20 bitrate=35490.3kbits/s speed=0.0625x
#
# frame=314
#
# fps=3.78
#
# stream_0_1_q=24.0
#
# bitrate=35490.3kbits/s
#
# total_size=23068720
#
# out_time_us=5200000
#
# out_time_ms=5200000
#
# out_time=00:00:05.200000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0625x
#
# progress=continue
#
# frame=  317 fps=3.8 q=23.0 size=   22528KiB time=00:00:05.25 bitrate=35152.3kbits/s speed=0.0627x
#
# frame=317
#
# fps=3.79
#
# stream_0_1_q=23.0
#
# bitrate=35152.3kbits/s
#
# total_size=23068720
#
# out_time_us=5250000
#
# out_time_ms=5250000
#
# out_time=00:00:05.250000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0627x
#
# progress=continue
#
# frame=  322 fps=3.8 q=24.0 size=   23040KiB time=00:00:05.33 bitrate=35389.5kbits/s speed=0.0633x
#
# frame=322
#
# fps=3.82
#
# stream_0_1_q=24.0
#
# bitrate=35389.5kbits/s
#
# total_size=23593008
#
# out_time_us=5333333
#
# out_time_ms=5333333
#
# out_time=00:00:05.333333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0633x
#
# progress=continue
#
# frame=  327 fps=3.9 q=25.0 size=   23296KiB time=00:00:05.41 bitrate=35232.2kbits/s speed=0.0639x
#
# frame=327
#
# fps=3.86
#
# stream_0_1_q=25.0
#
# bitrate=35232.2kbits/s
#
# total_size=23855152
#
# out_time_us=5416667
#
# out_time_ms=5416667
#
# out_time=00:00:05.416667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0639x
#
# progress=continue
#
# frame=  332 fps=3.9 q=25.0 size=   23552KiB time=00:00:05.50 bitrate=35079.7kbits/s speed=0.0645x
#
# frame=332
#
# fps=3.89
#
# stream_0_1_q=25.0
#
# bitrate=35079.7kbits/s
#
# total_size=24117296
#
# out_time_us=5500000
#
# out_time_ms=5500000
#
# out_time=00:00:05.500000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0645x
#
# progress=continue
#
# frame=  336 fps=3.9 q=25.0 size=   23808KiB time=00:00:05.56 bitrate=35036.3kbits/s speed=0.0649x
#
# frame=336
#
# fps=3.92
#
# stream_0_1_q=25.0
#
# bitrate=35036.3kbits/s
#
# total_size=24379440
#
# out_time_us=5566667
#
# out_time_ms=5566667
#
# out_time=00:00:05.566667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0649x
#
# progress=continue
#
# frame=  341 fps=4.0 q=23.0 size=   24064KiB time=00:00:05.65 bitrate=34890.7kbits/s speed=0.0655x
#
# frame=341
#
# fps=3.95
#
# stream_0_1_q=23.0
#
# bitrate=34890.7kbits/s
#
# total_size=24641584
#
# out_time_us=5650000
#
# out_time_ms=5650000
#
# out_time=00:00:05.650000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0655x
#
# progress=continue
#
# frame=  346 fps=4.0 q=24.0 size=   24576KiB time=00:00:05.73 bitrate=35115.2kbits/s speed=0.066x
#
# frame=346
#
# fps=3.99
#
# stream_0_1_q=24.0
#
# bitrate=35115.2kbits/s
#
# total_size=25165872
#
# out_time_us=5733333
#
# out_time_ms=5733333
#
# out_time=00:00:05.733333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.066x
#
# progress=continue
#
# frame=  350 fps=4.0 q=24.0 size=   24832KiB time=00:00:05.80 bitrate=35073.1kbits/s speed=0.0664x
#
# frame=350
#
# fps=4.01
#
# stream_0_1_q=24.0
#
# bitrate=35073.1kbits/s
#
# total_size=25428016
#
# out_time_us=5800000
#
# out_time_ms=5800000
#
# out_time=00:00:05.800000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0664x
#
# progress=continue
#
# frame=  354 fps=4.0 q=24.0 size=   25088KiB time=00:00:05.86 bitrate=35032.0kbits/s speed=0.0668x
#
# frame=354
#
# fps=4.03
#
# stream_0_1_q=24.0
#
# bitrate=35032.0kbits/s
#
# total_size=25690160
#
# out_time_us=5866667
#
# out_time_ms=5866667
#
# out_time=00:00:05.866667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0668x
#
# progress=continue
#
# frame=  359 fps=4.1 q=25.0 size=   25344KiB time=00:00:05.95 bitrate=34893.9kbits/s speed=0.0673x
#
# frame=359
#
# fps=4.06
#
# stream_0_1_q=25.0
#
# bitrate=34893.9kbits/s
#
# total_size=25952304
#
# out_time_us=5950000
#
# out_time_ms=5950000
#
# out_time=00:00:05.950000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0673x
#
# progress=continue
#
# frame=  364 fps=4.1 q=25.0 size=   25600KiB time=00:00:06.03 bitrate=34759.5kbits/s speed=0.0679x
#
# frame=364
#
# fps=4.10
#
# stream_0_1_q=25.0
#
# bitrate=34759.5kbits/s
#
# total_size=26214448
#
# out_time_us=6033333
#
# out_time_ms=6033333
#
# out_time=00:00:06.033333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0679x
#
# progress=continue
#
# frame=  369 fps=4.1 q=23.0 size=   26112KiB time=00:00:06.11 bitrate=34971.6kbits/s speed=0.0684x
#
# frame=369
#
# fps=4.13
#
# stream_0_1_q=23.0
#
# bitrate=34971.6kbits/s
#
# total_size=26738736
#
# out_time_us=6116667
#
# out_time_ms=6116667
#
# out_time=00:00:06.116667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0684x
#
# progress=continue
#
# frame=  374 fps=4.2 q=24.0 size=   26368KiB time=00:00:06.20 bitrate=34839.8kbits/s speed=0.069x
#
# frame=374
#
# fps=4.16
#
# stream_0_1_q=24.0
#
# bitrate=34839.8kbits/s
#
# total_size=27000880
#
# out_time_us=6200000
#
# out_time_ms=6200000
#
# out_time=00:00:06.200000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.069x
#
# progress=continue
#
# frame=  378 fps=4.2 q=24.0 size=   26624KiB time=00:00:06.26 bitrate=34803.9kbits/s speed=0.0693x
#
# frame=378
#
# fps=4.18
#
# stream_0_1_q=24.0
#
# bitrate=34803.9kbits/s
#
# total_size=27263024
#
# out_time_us=6266667
#
# out_time_ms=6266667
#
# out_time=00:00:06.266667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0693x
#
# progress=continue
#
# frame=  383 fps=4.2 q=25.0 size=   26880KiB time=00:00:06.35 bitrate=34677.4kbits/s speed=0.0698x
#
# frame=383
#
# fps=4.21
#
# stream_0_1_q=25.0
#
# bitrate=34677.4kbits/s
#
# total_size=27525168
#
# out_time_us=6350000
#
# out_time_ms=6350000
#
# out_time=00:00:06.350000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0698x
#
# progress=continue
#
# frame=  389 fps=4.3 q=23.0 size=   27392KiB time=00:00:06.45 bitrate=34790.0kbits/s speed=0.0705x
#
# frame=389
#
# fps=4.25
#
# stream_0_1_q=23.0
#
# bitrate=34790.0kbits/s
#
# total_size=28049456
#
# out_time_us=6450000
#
# out_time_ms=6450000
#
# out_time=00:00:06.450000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0705x
#
# progress=continue
#
# frame=  393 fps=4.3 q=22.0 size=   27392KiB time=00:00:06.51 bitrate=34434.1kbits/s speed=0.0708x
#
# frame=393
#
# fps=4.27
#
# stream_0_1_q=22.0
#
# bitrate=34434.1kbits/s
#
# total_size=28049456
#
# out_time_us=6516667
#
# out_time_ms=6516667
#
# out_time=00:00:06.516667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0708x
#
# progress=continue
#
# frame=  398 fps=4.3 q=23.0 size=   27904KiB time=00:00:06.60 bitrate=34634.8kbits/s speed=0.0713x
#
# frame=398
#
# fps=4.30
#
# stream_0_1_q=23.0
#
# bitrate=34634.8kbits/s
#
# total_size=28573744
#
# out_time_us=6600000
#
# out_time_ms=6600000
#
# out_time=00:00:06.600000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0713x
#
# progress=continue
#
# frame=  403 fps=4.3 q=24.0 size=   27904KiB time=00:00:06.68 bitrate=34203.0kbits/s speed=0.0718x
#
# frame=403
#
# fps=4.33
#
# stream_0_1_q=24.0
#
# bitrate=34203.0kbits/s
#
# total_size=28573744
#
# out_time_us=6683333
#
# out_time_ms=6683333
#
# out_time=00:00:06.683333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0718x
#
# progress=continue
#
# frame=  408 fps=4.4 q=25.0 size=   28160KiB time=00:00:06.76 bitrate=34091.7kbits/s speed=0.0723x
#
# frame=408
#
# fps=4.36
#
# stream_0_1_q=25.0
#
# bitrate=34091.7kbits/s
#
# total_size=28835888
#
# out_time_us=6766667
#
# out_time_ms=6766667
#
# out_time=00:00:06.766667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0723x
#
# progress=continue
#
# frame=  413 fps=4.4 q=22.0 size=   28672KiB time=00:00:06.85 bitrate=34289.3kbits/s speed=0.0728x
#
# frame=413
#
# fps=4.39
#
# stream_0_1_q=22.0
#
# bitrate=34289.3kbits/s
#
# total_size=29360176
#
# out_time_us=6850000
#
# out_time_ms=6850000
#
# out_time=00:00:06.850000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0728x
#
# progress=continue
#
# frame=  418 fps=4.4 q=24.0 size=   28928KiB time=00:00:06.93 bitrate=34179.6kbits/s speed=0.0733x
#
# frame=418
#
# fps=4.42
#
# stream_0_1_q=24.0
#
# bitrate=34179.6kbits/s
#
# total_size=29622320
#
# out_time_us=6933333
#
# out_time_ms=6933333
#
# out_time=00:00:06.933333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0733x
#
# progress=continue
#
# frame=  423 fps=4.4 q=25.0 size=   29184KiB time=00:00:07.01 bitrate=34072.5kbits/s speed=0.0737x
#
# frame=423
#
# fps=4.45
#
# stream_0_1_q=25.0
#
# bitrate=34072.5kbits/s
#
# total_size=29884464
#
# out_time_us=7016667
#
# out_time_ms=7016667
#
# out_time=00:00:07.016667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0737x
#
# progress=continue
#
# frame=  427 fps=4.5 q=25.0 size=   29440KiB time=00:00:07.08 bitrate=34047.9kbits/s speed=0.074x
#
# frame=427
#
# fps=4.46
#
# stream_0_1_q=25.0
#
# bitrate=34047.9kbits/s
#
# total_size=30146608
#
# out_time_us=7083333
#
# out_time_ms=7083333
#
# out_time=00:00:07.083333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.074x
#
# progress=continue
#
# frame=  432 fps=4.5 q=25.0 size=   29696KiB time=00:00:07.16 bitrate=33944.7kbits/s speed=0.0745x
#
# frame=432
#
# fps=4.49
#
# stream_0_1_q=25.0
#
# bitrate=33944.7kbits/s
#
# total_size=30408752
#
# out_time_us=7166667
#
# out_time_ms=7166667
#
# out_time=00:00:07.166667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0745x
#
# progress=continue
#
# frame=  436 fps=4.5 q=25.0 size=   29952KiB time=00:00:07.23 bitrate=33921.7kbits/s speed=0.0748x
#
# frame=436
#
# fps=4.51
#
# stream_0_1_q=25.0
#
# bitrate=33921.7kbits/s
#
# total_size=30670896
#
# out_time_us=7233333
#
# out_time_ms=7233333
#
# out_time=00:00:07.233333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0748x
#
# progress=continue
#
# frame=  441 fps=4.5 q=23.0 size=   30208KiB time=00:00:07.31 bitrate=33822.0kbits/s speed=0.0752x
#
# frame=441
#
# fps=4.53
#
# stream_0_1_q=23.0
#
# bitrate=33822.0kbits/s
#
# total_size=30933040
#
# out_time_us=7316667
#
# out_time_ms=7316667
#
# out_time=00:00:07.316667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0752x
#
# progress=continue
#
# frame=  446 fps=4.6 q=24.0 size=   30720KiB time=00:00:07.40 bitrate=34007.9kbits/s speed=0.0757x
#
# frame=446
#
# fps=4.56
#
# stream_0_1_q=24.0
#
# bitrate=34007.9kbits/s
#
# total_size=31457328
#
# out_time_us=7400000
#
# out_time_ms=7400000
#
# out_time=00:00:07.400000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0757x
#
# progress=continue
#
# frame=  452 fps=4.6 q=25.0 size=   30976KiB time=00:00:07.50 bitrate=33834.1kbits/s speed=0.0763x
#
# frame=452
#
# fps=4.60
#
# stream_0_1_q=25.0
#
# bitrate=33834.1kbits/s
#
# total_size=31719472
#
# out_time_us=7500000
#
# out_time_ms=7500000
#
# out_time=00:00:07.500000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0763x
#
# progress=continue
#
# frame=  456 fps=4.6 q=25.0 size=   31232KiB time=00:00:07.56 bitrate=33813.2kbits/s speed=0.0766x
#
# frame=456
#
# fps=4.61
#
# stream_0_1_q=25.0
#
# bitrate=33813.2kbits/s
#
# total_size=31981616
#
# out_time_us=7566667
#
# out_time_ms=7566667
#
# out_time=00:00:07.566667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0766x
#
# progress=continue
#
# frame=  461 fps=4.6 q=22.0 size=   31488KiB time=00:00:07.65 bitrate=33719.0kbits/s speed=0.077x
#
# frame=461
#
# fps=4.64
#
# stream_0_1_q=22.0
#
# bitrate=33719.0kbits/s
#
# total_size=32243760
#
# out_time_us=7650000
#
# out_time_ms=7650000
#
# out_time=00:00:07.650000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.077x
#
# progress=continue
#
# frame=  466 fps=4.7 q=23.0 size=   31744KiB time=00:00:07.73 bitrate=33626.8kbits/s speed=0.0774x
#
# frame=466
#
# fps=4.66
#
# stream_0_1_q=23.0
#
# bitrate=33626.8kbits/s
#
# total_size=32505904
#
# out_time_us=7733333
#
# out_time_ms=7733333
#
# out_time=00:00:07.733333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0774x
#
# progress=continue
#
# frame=  471 fps=4.7 q=24.0 size=   32000KiB time=00:00:07.81 bitrate=33536.6kbits/s speed=0.0778x
#
# frame=471
#
# fps=4.69
#
# stream_0_1_q=24.0
#
# bitrate=33536.6kbits/s
#
# total_size=32768048
#
# out_time_us=7816667
#
# out_time_ms=7816667
#
# out_time=00:00:07.816667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0778x
#
# progress=continue
#
# frame=  476 fps=4.7 q=25.0 size=   32256KiB time=00:00:07.90 bitrate=33448.3kbits/s speed=0.0783x
#
# frame=476
#
# fps=4.72
#
# stream_0_1_q=25.0
#
# bitrate=33448.3kbits/s
#
# total_size=33030192
#
# out_time_us=7900000
#
# out_time_ms=7900000
#
# out_time=00:00:07.900000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0783x
#
# progress=continue
#
# frame=  481 fps=4.7 q=22.0 size=   32512KiB time=00:00:07.98 bitrate=33361.8kbits/s speed=0.0787x
#
# frame=481
#
# fps=4.74
#
# stream_0_1_q=22.0
#
# bitrate=33361.8kbits/s
#
# total_size=33292336
#
# out_time_us=7983333
#
# out_time_ms=7983333
#
# out_time=00:00:07.983333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0787x
#
# progress=continue
#
# frame=  486 fps=4.8 q=23.0 size=   32768KiB time=00:00:08.06 bitrate=33277.2kbits/s speed=0.0791x
#
# frame=486
#
# fps=4.76
#
# stream_0_1_q=23.0
#
# bitrate=33277.2kbits/s
#
# total_size=33554480
#
# out_time_us=8066667
#
# out_time_ms=8066667
#
# out_time=00:00:08.066667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0791x
#
# progress=continue
#
# frame=  490 fps=4.8 q=21.0 size=   33024KiB time=00:00:08.13 bitrate=33262.3kbits/s speed=0.0793x
#
# frame=490
#
# fps=4.78
#
# stream_0_1_q=21.0
#
# bitrate=33262.3kbits/s
#
# total_size=33816624
#
# out_time_us=8133333
#
# out_time_ms=8133333
#
# out_time=00:00:08.133333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0793x
#
# progress=continue
#
# frame=  495 fps=4.8 q=23.0 size=   33280KiB time=00:00:08.21 bitrate=33180.1kbits/s speed=0.0797x
#
# frame=495
#
# fps=4.80
#
# stream_0_1_q=23.0
#
# bitrate=33180.1kbits/s
#
# total_size=34078768
#
# out_time_us=8216667
#
# out_time_ms=8216667
#
# out_time=00:00:08.216667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0797x
#
# progress=continue
#
# frame=  500 fps=4.8 q=24.0 size=   33536KiB time=00:00:08.30 bitrate=33099.7kbits/s speed=0.0801x
#
# frame=500
#
# fps=4.83
#
# stream_0_1_q=24.0
#
# bitrate=33099.7kbits/s
#
# total_size=34340912
#
# out_time_us=8300000
#
# out_time_ms=8300000
#
# out_time=00:00:08.300000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0801x
#
# progress=continue
#
# frame=  505 fps=4.9 q=25.0 size=   34304KiB time=00:00:08.38 bitrate=33521.1kbits/s speed=0.0805x
#
# frame=505
#
# fps=4.85
#
# stream_0_1_q=25.0
#
# bitrate=33521.1kbits/s
#
# total_size=35127344
#
# out_time_us=8383333
#
# out_time_ms=8383333
#
# out_time=00:00:08.383333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0805x
#
# progress=continue
#
# frame=  510 fps=4.9 q=25.0 size=   34560KiB time=00:00:08.46 bitrate=33438.9kbits/s speed=0.0809x
#
# frame=510
#
# fps=4.87
#
# stream_0_1_q=25.0
#
# bitrate=33438.9kbits/s
#
# total_size=35389488
#
# out_time_us=8466667
#
# out_time_ms=8466667
#
# out_time=00:00:08.466667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0809x
#
# progress=continue
#
# frame=  515 fps=4.9 q=22.0 size=   34816KiB time=00:00:08.55 bitrate=33358.3kbits/s speed=0.0813x
#
# frame=515
#
# fps=4.90
#
# stream_0_1_q=22.0
#
# bitrate=33358.3kbits/s
#
# total_size=35651632
#
# out_time_us=8550000
#
# out_time_ms=8550000
#
# out_time=00:00:08.550000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0813x
#
# progress=continue
#
# frame=  519 fps=4.9 q=22.0 size=   35072KiB time=00:00:08.61 bitrate=33343.5kbits/s speed=0.0815x
#
# frame=519
#
# fps=4.91
#
# stream_0_1_q=22.0
#
# bitrate=33343.5kbits/s
#
# total_size=35913776
#
# out_time_us=8616667
#
# out_time_ms=8616667
#
# out_time=00:00:08.616667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0815x
#
# progress=continue
#
# frame=  524 fps=4.9 q=23.0 size=   35328KiB time=00:00:08.70 bitrate=33265.2kbits/s speed=0.0819x
#
# frame=524
#
# fps=4.93
#
# stream_0_1_q=23.0
#
# bitrate=33265.2kbits/s
#
# total_size=36175920
#
# out_time_us=8700000
#
# out_time_ms=8700000
#
# out_time=00:00:08.700000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0819x
#
# progress=continue
#
# frame=  529 fps=5.0 q=24.0 size=   35584KiB time=00:00:08.78 bitrate=33188.4kbits/s speed=0.0823x
#
# frame=529
#
# fps=4.96
#
# stream_0_1_q=24.0
#
# bitrate=33188.4kbits/s
#
# total_size=36438064
#
# out_time_us=8783333
#
# out_time_ms=8783333
#
# out_time=00:00:08.783333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0823x
#
# progress=continue
#
# frame=  534 fps=5.0 q=24.0 size=   35840KiB time=00:00:08.86 bitrate=33113.0kbits/s speed=0.0827x
#
# frame=534
#
# fps=4.98
#
# stream_0_1_q=24.0
#
# bitrate=33113.0kbits/s
#
# total_size=36700208
#
# out_time_us=8866667
#
# out_time_ms=8866667
#
# out_time=00:00:08.866667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0827x
#
# progress=continue
#
# frame=  538 fps=5.0 q=24.0 size=   35840KiB time=00:00:08.93 bitrate=32865.9kbits/s speed=0.0829x
#
# frame=538
#
# fps=4.99
#
# stream_0_1_q=24.0
#
# bitrate=32865.9kbits/s
#
# total_size=36700208
#
# out_time_us=8933333
#
# out_time_ms=8933333
#
# out_time=00:00:08.933333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0829x
#
# progress=continue
#
# frame=  543 fps=5.0 q=22.0 size=   36352KiB time=00:00:09.01 bitrate=33027.3kbits/s speed=0.0833x
#
# frame=543
#
# fps=5.01
#
# stream_0_1_q=22.0
#
# bitrate=33027.3kbits/s
#
# total_size=37224496
#
# out_time_us=9016667
#
# out_time_ms=9016667
#
# out_time=00:00:09.016667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0833x
#
# progress=continue
#
# frame=  548 fps=5.0 q=23.0 size=   36608KiB time=00:00:09.10 bitrate=32955.3kbits/s speed=0.0836x
#
# frame=548
#
# fps=5.04
#
# stream_0_1_q=23.0
#
# bitrate=32955.3kbits/s
#
# total_size=37486640
#
# out_time_us=9100000
#
# out_time_ms=9100000
#
# out_time=00:00:09.100000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0836x
#
# progress=continue
#
# frame=  553 fps=5.1 q=24.0 size=   36864KiB time=00:00:09.18 bitrate=32884.6kbits/s speed=0.084x
#
# frame=553
#
# fps=5.06
#
# stream_0_1_q=24.0
#
# bitrate=32884.6kbits/s
#
# total_size=37748784
#
# out_time_us=9183333
#
# out_time_ms=9183333
#
# out_time=00:00:09.183333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.084x
#
# progress=continue
#
# frame=  557 fps=5.1 q=24.0 size=   36864KiB time=00:00:09.25 bitrate=32647.6kbits/s speed=0.0842x
#
# frame=557
#
# fps=5.07
#
# stream_0_1_q=24.0
#
# bitrate=32647.6kbits/s
#
# total_size=37748784
#
# out_time_us=9250000
#
# out_time_ms=9250000
#
# out_time=00:00:09.250000
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0842x
#
# progress=continue
#
# frame=  562 fps=5.1 q=24.0 size=   37120KiB time=00:00:09.33 bitrate=32580.8kbits/s speed=0.0846x
#
# frame=562
#
# fps=5.09
#
# stream_0_1_q=24.0
#
# bitrate=32580.8kbits/s
#
# total_size=38010928
#
# out_time_us=9333333
#
# out_time_ms=9333333
#
# out_time=00:00:09.333333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0846x
#
# progress=continue
#
# frame=  567 fps=5.1 q=22.0 size=   37376KiB time=00:00:09.41 bitrate=32515.2kbits/s speed=0.0849x
#
# frame=567
#
# fps=5.11
#
# stream_0_1_q=22.0
#
# bitrate=32515.2kbits/s
#
# total_size=38273072
#
# out_time_us=9416667
#
# out_time_ms=9416667
#
# out_time=00:00:09.416667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0849x
#
# progress=continue
#
# frame=  573 fps=5.1 q=24.0 size=   37632KiB time=00:00:09.51 bitrate=32393.9kbits/s speed=0.0854x
#
# frame=573
#
# fps=5.14
#
# stream_0_1_q=24.0
#
# bitrate=32393.9kbits/s
#
# total_size=38535216
#
# out_time_us=9516667
#
# out_time_ms=9516667
#
# out_time=00:00:09.516667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0854x
#
# progress=continue
#
# frame=  577 fps=5.2 q=24.0 size=   37888KiB time=00:00:09.58 bitrate=32387.4kbits/s speed=0.0856x
#
# frame=577
#
# fps=5.15
#
# stream_0_1_q=24.0
#
# bitrate=32387.4kbits/s
#
# total_size=38797360
#
# out_time_us=9583333
#
# out_time_ms=9583333
#
# out_time=00:00:09.583333
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0856x
#
# progress=continue
#
# frame=  592 fps=5.3 q=-1.0 size=   38656KiB time=N/A bitrate=N/A speed=N/A
#
# frame=592
#
# fps=5.26
#
# stream_0_1_q=-1.0
#
# bitrate=N/A
#
# total_size=39583792
#
# out_time_us=N/A
#
# out_time_ms=N/A
#
# out_time=N/A
#
# dup_frames=0
#
# drop_frames=0
#
# speed=N/A
#
# progress=continue
#
# [out#0/mp4 @ 000001654ea7f700] video:39050KiB audio:157KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.043370%
#
# frame=  600 fps=5.3 q=-1.0 Lsize=   39223KiB time=00:00:09.96 bitrate=32239.3kbits/s speed=0.0885x
#
# frame=600
#
# fps=5.33
#
# stream_0_1_q=-1.0
#
# bitrate=32239.3kbits/s
#
# total_size=40164799
#
# out_time_us=9966667
#
# out_time_ms=9966667
#
# out_time=00:00:09.966667
#
# dup_frames=0
#
# drop_frames=0
#
# speed=0.0885x
#
# progress=end
#
# [aac @ 000001654fef06c0] Qavg: 411.244
#
# [libx264 @ 000001654fbff6c0] frame I:3     Avg QP:17.46  size:695807
#
# [libx264 @ 000001654fbff6c0] frame P:151   Avg QP:20.07  size:171487
#
# [libx264 @ 000001654fbff6c0] frame B:446   Avg QP:20.31  size: 26916
#
# [libx264 @ 000001654fbff6c0] consecutive B-frames:  0.8%  0.0%  0.5% 98.7%
#
# [libx264 @ 000001654fbff6c0] mb I  I16..4: 12.1% 43.1% 44.7%
#
# [libx264 @ 000001654fbff6c0] mb P  I16..4:  6.1% 14.8%  1.7%  P16..4: 44.3%  0.0%  0.0%  0.0%  0.0%    skip:33.1%
#
# [libx264 @ 000001654fbff6c0] mb B  I16..4:  0.5%  0.5%  0.0%  B16..8: 11.8%  0.0%  0.0%  direct:10.3%  skip:76.9%  L0:36.1% L1:54.0% BI: 9.9%
#
# [libx264 @ 000001654fbff6c0] 8x8 transform intra:62.3% inter:36.6%
#
# [libx264 @ 000001654fbff6c0] coded y,uvDC,uvAC intra: 63.9% 54.4% 11.7% inter: 7.1% 11.7% 0.1%
#
# [libx264 @ 000001654fbff6c0] i16 v,h,dc,p: 29% 24% 27% 20%
#
# [libx264 @ 000001654fbff6c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 21% 25%  6%  6%  5%  8%  5%  9%
#
# [libx264 @ 000001654fbff6c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 29% 13%  6%  5%  5%  7%  5%  7%
#
# [libx264 @ 000001654fbff6c0] i8c dc,h,v,p: 37% 27% 25% 11%
#
# [libx264 @ 000001654fbff6c0] Weighted P-Frames: Y:0.0% UV:0.0%
#
# [libx264 @ 000001654fbff6c0] kb/s:31989.00
#
# FFMPEG has finished processing.
